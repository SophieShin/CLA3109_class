# %% [markdown]
# ##### Q1. (UNIX) 디렉토리 내에 있는 파일들의 목록을 내림차순으로 출력하는 명령어를 적으세요. ( ! 기호 후 명령어 입력. Windows 명령어도 인정함. )

# %%
# ls | sort -r 또는 dir /o-n (Windows)

# %% [markdown]
# ##### 3주차 강의안 10페이지 참조

# %% [markdown]
# ##### Q2. (UNIX) UNIX에서는 모든 것이 \_\_이것\_\_이다. 이것에 들어갈 말을 영어로 적으세요.

# %%
# File

# %% [markdown]
# ##### 2주차 강의안 17페이지 참조 <br> Ref) Tree 구조

# %% [markdown]
# ##### Q3. 다음 리스트에서 짝수만 남기면서, 892 보다 큰 수는 출력되지 않는 리스트를 만드세요.

# %%
numbers = [    
    386, 462, 47, 418, 907, 344, 236, 375, 823, 566, 597, 978, 328, 615, 953, 345, 
    399, 162, 758, 219, 918, 237, 412, 566, 826, 248, 866, 950, 626, 949, 687, 217, 
    815, 67, 104, 58, 512, 24, 892, 894, 767, 553, 81, 379, 843, 831, 445, 742, 717, 
    958,743, 527
    ]

numbers = [n for n in numbers if (n%2==0) and (n<=892)]
numbers

# %% [markdown]
# ##### Q4. 다음 2개의 변수 a, b의 값을 한 줄로 바꾸는 코드를 완성하세요.

# %%
young_man = "신하균"
old_man = "변희봉"
old_man, young_man = young_man, old_man
print(young_man, old_man)

# %% [markdown]
# ##### 변수 swapping

# %% [markdown]
# ##### Q5. 한국어의 목적격 조사 '을'과 '를'은 앞에 나오는 단어의 받침에 따라 결정된다. 예를 들어, "나는 오늘 수업을 들었다."에서 "수업" 뒤에 붙는 목적격 조사 "을"은 앞 음절에 받침이 있기 때문에 "을"을 사용한 것이다. 만일, 앞 음절에 받침이 없었다면 "를"을 사용했을 것이다. 입력으로 넣은 단어의 목적격 조사로 '을'과 '를' 중 어떤 것이 적절할 지 판단하는 함수를 작성하세요.

# %%
# 참고
# 초성 리스트. 00 ~ 18
CHOSUNG_LIST = ['ㄱ', 'ㄲ', 'ㄴ', 'ㄷ', 'ㄸ', 'ㄹ', 'ㅁ', 'ㅂ', 'ㅃ', 'ㅅ', 'ㅆ', 'ㅇ', 'ㅈ', 'ㅉ', 'ㅊ', 'ㅋ', 'ㅌ', 'ㅍ', 'ㅎ']
# 중성 리스트. 00 ~ 20
JUNGSUNG_LIST = ['ㅏ', 'ㅐ', 'ㅑ', 'ㅒ', 'ㅓ', 'ㅔ', 'ㅕ', 'ㅖ', 'ㅗ', 'ㅘ', 'ㅙ', 'ㅚ', 'ㅛ', 'ㅜ', 'ㅝ', 'ㅞ', 'ㅟ', 'ㅠ', 'ㅡ', 'ㅢ', 'ㅣ']
# 종성 리스트. 00 ~ 27 + 1(1개 없음)
JONGSUNG_LIST = [' ', 'ㄱ', 'ㄲ', 'ㄳ', 'ㄴ', 'ㄵ', 'ㄶ', 'ㄷ', 'ㄹ', 'ㄺ', 'ㄻ', 'ㄼ', 'ㄽ', 'ㄾ', 'ㄿ', 'ㅀ', 'ㅁ', 'ㅂ', 'ㅄ', 'ㅅ', 'ㅆ', 'ㅇ', 'ㅈ', 'ㅊ', 'ㅋ', 'ㅌ', 'ㅍ', 'ㅎ']

def decide_postposition(word):
    last_syllable = word[-1]
    gap = ord('개') - ord('가')
    if ((ord(last_syllable)-ord('가')) % gap) == 0:
        return word+"를"
    else:
        return word+"을"
decide_postposition("여수 밤바다") # 실행 결과 "여수 밤바다를"이 출력되어야 함.

# %% [markdown]
# ##### Q6. 다음 문자열을 역순으로 출력하는 한 줄짜리 코드를 작성하세요.

# %%
sentence = "로꾸꺼 로꾸꺼 로꾸꺼 말해말"
sentence = sentence[::-1]
sentence

# %% [markdown]
# ##### Q7. 주어진 dictionary가 모두 같은 값을 갖고 있는지 확인하는 함수를 작성하세요.

# %%
def check_homogeneity(dictionary):
    return (True if len(set(dictionary.values())) == 1 else False)
print(check_homogeneity({"정조":"왕", "단종":"왕", "광해군":"왕"})) # return True
print(check_homogeneity({"걸스데이":4, "씨스타":4, "블랭핑크":4, "소녀시대":9})) # return False

# %% [markdown]
# ##### 삼항연산자

# %% [markdown]
# ##### Q8. 다음 두 리스트 s1, s2를 Pandas의 Series로 만들고 두 Series를 더해보세요.

# %%
import pandas as pd
s1 = [2, 4, 6, 8, 10]
s2 = [1, 3, 5, 7, 9]
s1 = pd.Series(s1)
s2 = pd.Series(s2)
s1+s2

# %% [markdown]
# ##### Q9. 다음 DataFrame 에서, name(이름)과 turnout(득표율)만 선택(selection)하는 코드를 작성하세요.

# %%
import pandas as pd
import numpy as np
president_data  = {'name': ['이승만', '윤보선', '박정희', '최규하', '전두환', '노태우',
                       '김영삼', '김대중', '노무현', '이명박', '박근혜', '문재인'],
        'turnout': [91.8, 79.1, 46.6, 96.3, 99.4, 36.6,
                    42, 40.3, 48.9, 48.7, 51.6,41.1],
        'jail': ['no', 'no', 'no', 'no', 'yes', 'yes',
                'no', 'no', 'no','yes','yes',np.nan]}
labels = ['가', '나', '다', '라', '마', '바', '사', '아', '자', '차','카','타']
presidents = pd.DataFrame(president_data, index=labels )

presidents[['name','turnout']]

# %% [markdown]
# ##### Q10. Q9 에서 만든 DataFrame에 각 대통령의 재임 기간을 조사하여 'period'라는 column을 만들고, 'period'의 내림차순으로 DataFrame을 정렬하세요.

# %%
presidents['period'] = [4273, 588, 5793, 255, 2733, 1827, 1826, 1825, 1826, 1827, 1474, 1780]
presidents.sort_values('period')

# %% [markdown]
# ##### [https://ko.wikipedia.org/wiki/대한민국의_대통령_목록](https://ko.wikipedia.org/wiki/%EB%8C%80%ED%95%9C%EB%AF%BC%EA%B5%AD%EC%9D%98_%EB%8C%80%ED%86%B5%EB%A0%B9_%EB%AA%A9%EB%A1%9D)
# ```이승만: 4273일(11년 8개월 11일)
# 윤보선: 588일(1년 7개월 10일)
# 박정희: 5793일(15년 10개월 9일)
# 최규하: 255일(8개월 10일)
# 전두환: 2733일(7년 5개월 23일)
# 노태우: 1827일(5년)
# 김영삼: 1826일(5년)
# 김대중: 1825일(5년)
# 노무현: 1826일(5년)
# 이명박: 1827일(5년)
# 박근혜: 1474일(4년 13일)```

# %% [markdown]
# ### Q1. 다음 조선왕조실록 사이트에서 재위기간이 가장 짧은 인종의 기사를 크롤링하여 1) URL 주소, 2) 기사 제목, 3) 한글 내용을 포함하는 코드를 작성 하세요. [조선왕조실록 바로가기](http://sillok.history.go.kr/main/main.do) <br><br> 예상되는 output은 다음과 같습니다.
# ```[{"url": "http://sillok.history.go.kr/id/kla_10101001_001", "title":"삭전을 지내고 상식을 올리다", "content": "상(上)이 삭전(朔奠)을 지내고..." }, {"url":"...", "title":"...", "content":"..."}, ...]```

# %%
from selenium import webdriver
import requests
from lxml import html
from selenium.webdriver.common.by import By
chrome_options = webdriver.ChromeOptions()
# 브라우저에 임의로 User-agent 옵션을 넣어 Python 코드로 접속함을 숨김
chrome_options.add_argument('--user-agent="Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3359.139 Safari/537.36"')
driver = webdriver.Chrome(chrome_options=chrome_options)
# Out:
# <ipython-input-31-02e110f7e166>:8: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(chrome_options=chrome_options)

# %%
driver.get("http://sillok.history.go.kr/main/main.do")
driver.find_element(By.XPATH, '//*[@id="m_cont_list"]/div[1]/ul[2]/li[4]/a').click()
# driver.find_element(By.LINK_TEXT, '12대 인종(1545년~)').click()
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-30-ac8d7ce33ce7> in <module>
# ----> 1 driver.get("http://sillok.history.go.kr/main/main.do")
#       2 driver.find_element(By.XPATH, '//*[@id="m_cont_list"]/div[1]/ul[2]/li[4]/a').click()
#       3 # driver.find_element(By.LINK_TEXT, '12대 인종(1545년~)').click()
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     435         Loads a web page in the current browser session.
#     436         """
# --> 437         self.execute(Command.GET, {'url': url})
#     438
#     439     @property
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     423         response = self.command_executor.execute(driver_command, params)
#     424         if response:
# --> 425             self.error_handler.check_response(response)
#     426             response['value'] = self._unwrap_value(
#     427                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# WebDriverException: Message: chrome not reachable
#   (Session info: chrome=99.0.4844.84)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x006D9943+2595139]
# 	Ordinal0 [0x0066C9F1+2148849]
# 	Ordinal0 [0x005643F0+1065968]
# 	Ordinal0 [0x005587C2+1017794]
# 	Ordinal0 [0x00558FF8+1019896]
# 	Ordinal0 [0x0055A892+1026194]
# 	Ordinal0 [0x00554219+999961]
# 	Ordinal0 [0x00565860+1071200]
# 	Ordinal0 [0x005BB2D2+1422034]
# 	Ordinal0 [0x005AB806+1357830]
# 	Ordinal0 [0x00586086+1204358]
# 	Ordinal0 [0x00586F96+1208214]
# 	GetHandleVerifier [0x0087B232+1658114]
# 	GetHandleVerifier [0x0093312C+2411516]
# 	GetHandleVerifier [0x0076F261+560433]
# 	GetHandleVerifier [0x0076E366+556598]
# 	Ordinal0 [0x0067286B+2173035]
# 	Ordinal0 [0x006775F8+2192888]
# 	Ordinal0 [0x006776E5+2193125]
# 	Ordinal0 [0x006811FC+2232828]
# 	BaseThreadInitThunk [0x75EBFA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x77567A7E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77567A4E+238]

# %%
months = driver.find_elements(By.XPATH, '//*[@id="cont_area"]/div/div[2]/ul[2]/li/ul/li/a')
months
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="541aa79de4b124a8b4f9c3ef57fced5e", element="cc3cf83f-6963-4b64-8af5-582326bda9a5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="541aa79de4b124a8b4f9c3ef57fced5e", element="cb677b95-e2af-4e3d-a93d-073c2ff2db4c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="541aa79de4b124a8b4f9c3ef57fced5e", element="90f5df3a-7ecd-4329-b29c-01e826b4b141")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="541aa79de4b124a8b4f9c3ef57fced5e", element="b666fe56-46d8-4705-8c40-a94f4bb9da62")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="541aa79de4b124a8b4f9c3ef57fced5e", element="1d303a0f-eb9c-49f9-9733-77fb485a9c3f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="541aa79de4b124a8b4f9c3ef57fced5e", element="f0eaae95-ea5e-477a-a967-9cc5d6b964ca")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="541aa79de4b124a8b4f9c3ef57fced5e", element="9b328365-bc1b-4c4b-9635-d11a81975f3c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="541aa79de4b124a8b4f9c3ef57fced5e", element="a14e44ef-4197-4dbf-97b4-e1634578b67c")>]

# %%
all_urls = []
for month in months:
    month.click()
    month_urls = [url.get_attribute("href") for url in driver.find_elements(By.XPATH,'//*[@id="cont_area"]/div[1]/div[3]/div/dl/dd/ul/li/a')]
    month_urls = [url.strip("javascript:searchView('").strip("');") for url in month_urls]
    month_urls = ['http://sillok.history.go.kr/id/'+url for url in month_urls]
    all_urls.append(month_urls)
    driver.back();
# Out:
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# <ipython-input-23-bcc8e523ff3e> in <module>
#       1 all_urls = []
#       2 for month in months:
# ----> 3     month.click()
#       4     month_urls = [url.get_attribute("href") for url in driver.find_elements(By.XPATH,'//*[@id="cont_area"]/div[1]/div[3]/div/dl/dd/ul/li/a')]
#       5     month_urls = [url.strip("javascript:searchView('").strip("');") for url in month_urls]
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      79     def click(self) -> None:
#      80         """Clicks the element."""
# ---> 81         self._execute(Command.CLICK_ELEMENT)
#      82
#      83     def submit(self):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     708             params = {}
#     709         params['id'] = self._id
# --> 710         return self._parent.execute(command, params)
#     711
#     712     def find_element(self, by=By.ID, value=None):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     423         response = self.command_executor.execute(driver_command, params)
#     424         if response:
# --> 425             self.error_handler.check_response(response)
#     426             response['value'] = self._unwrap_value(
#     427                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# StaleElementReferenceException: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=99.0.4844.84)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x006D9943+2595139]
# 	Ordinal0 [0x0066C9F1+2148849]
# 	Ordinal0 [0x00564528+1066280]
# 	Ordinal0 [0x00566E04+1076740]
# 	Ordinal0 [0x00566CBE+1076414]
# 	Ordinal0 [0x00566F50+1077072]
# 	Ordinal0 [0x0059290C+1255692]
# 	Ordinal0 [0x005879D6+1210838]
# 	Ordinal0 [0x005AB9EC+1358316]
# 	Ordinal0 [0x00587474+1209460]
# 	Ordinal0 [0x005ABC04+1358852]
# 	Ordinal0 [0x005BBAF2+1424114]
# 	Ordinal0 [0x005AB806+1357830]
# 	Ordinal0 [0x00586086+1204358]
# 	Ordinal0 [0x00586F96+1208214]
# 	GetHandleVerifier [0x0087B232+1658114]
# 	GetHandleVerifier [0x0093312C+2411516]
# 	GetHandleVerifier [0x0076F261+560433]
# 	GetHandleVerifier [0x0076E366+556598]
# 	Ordinal0 [0x0067286B+2173035]
# 	Ordinal0 [0x006775F8+2192888]
# 	Ordinal0 [0x006776E5+2193125]
# 	Ordinal0 [0x006811FC+2232828]
# 	BaseThreadInitThunk [0x75EBFA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x77567A7E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77567A4E+238]

# %%
months[0].click()

# %%
months[0].get_attribute('href')
# Out:
# "javascript:search('kla_101010', '7', '3');"

# %%
months[0].get_attribute('href').strip("javascript:searchView('").strip("');")
# Out:
# "kla_101010', '7', '3"

# %%
'http://sillock.history.go.kr/id/'+months[0].get_attribute('href').strip("javascript:searchView('").strip("');")
# Out:
# "http://sillock.history.go.kr/id/kla_101010', '7', '3"

# %%
# w3school 에서 XPATH 공부하기!

# %%
all_urls = []
for month in range(1,9):
    driver.get("http://sillok.history.go.kr/main/main.do") #홈페이지 클릭
    driver.find_element(By.XPATH, '//*[@id="m_cont_list"]/div[1]/ul[2]/li[4]/a').click() #인종 클릭
    months = driver.find_elements(By.XPATH, '//*[@id="cont_area"]/div/div[2]/ul[2]/li/ul/li['+str(month)+']/a') # 숫자를string으로 변환
    for month in months:
        month.click()
        month_urls = [url.get_attribute("href") for url in driver.find_elements(By.XPATH,'//*[@id="cont_area"]/div[1]/div[3]/div/dl/dd/ul/li/a')]
        month_urls = [url.strip("javascript:searchView('").strip("');") for url in month_urls]
        month_urls = ['http://sillok.history.go.kr/id/'+url for url in month_urls]
        all_urls.extend(month_urls)
    # append 대신 extend를 쓰기
    # get_attribute('href'값을 가져오기)

# %%
driver.get("http://sillok.history.go.kr/main/main.do") #홈페이지 클릭

# %%
driver.find_element(By.XPATH, '//*[@id="m_cont_list"]/div[1]/ul[2]/li[4]/a').click() #인종 클릭

# %%
driver.find_elements(By.XPATH, '//*[@id="cont_area"]/div/div[2]/ul[2]/li/ul/li[1]/a')[0].click()

# %%
driver.find_elements(By.XPATH,'//*[@id="cont_area"]/div[1]/div[3]/div/dl/dd/ul/li/a')[0].get_attribute('href')
# Out:
# "javascript:searchView('kla_10101001_001');"

# %%
url = driver.find_elements(By.XPATH,'//*[@id="cont_area"]/div[1]/div[3]/div/dl/dd/ul/li/a')[0].get_attribute('href').strip("javascript:searchView('").strip("');")
url
# Out:
# 'kla_10101001_001'

# %%
'http://sillok.history.go.kr/id/'+url
# Out:
# 'http://sillok.history.go.kr/id/kla_10101001_001'

# %%
all_urls
# Out:
# ['http://sillok.history.go.kr/id/kla_10101001_001',
#  'http://sillok.history.go.kr/id/kla_10101001_002',
#  'http://sillok.history.go.kr/id/kla_10101002_001',
#  'http://sillok.history.go.kr/id/kla_10101002_002',
#  'http://sillok.history.go.kr/id/kla_10101002_003',
#  'http://sillok.history.go.kr/id/kla_10101002_004',
#  'http://sillok.history.go.kr/id/kla_10101003_001',
#  'http://sillok.history.go.kr/id/kla_10101003_002',
#  'http://sillok.history.go.kr/id/kla_10101003_003',
#  'http://sillok.history.go.kr/id/kla_10101004_001',
#  'http://sillok.history.go.kr/id/kla_10101004_002',
#  'http://sillok.history.go.kr/id/kla_10101004_003',
#  'http://sillok.history.go.kr/id/kla_10101004_004',
#  'http://sillok.history.go.kr/id/kla_10101005_001',
#  'http://sillok.history.go.kr/id/kla_10101005_002',
#  'http://sillok.history.go.kr/id/kla_10101005_003',
#  'http://sillok.history.go.kr/id/kla_10101005_004',
#  'http://sillok.history.go.kr/id/kla_10101006_001',
#  'http://sillok.history.go.kr/id/kla_10101006_002',
#  'http://sillok.history.go.kr/id/kla_10101006_003',
#  'http://sillok.history.go.kr/id/kla_10106029_006',
#  'http://sillok.history.go.kr/id/kla_10106029_007',
#  'http://sillok.history.go.kr/id/kla_10106029_008',
#  'http://sillok.history.go.kr/id/kla_10106029_009',
#  'http://sillok.history.go.kr/id/kla_10106029_010',
#  'http://sillok.history.go.kr/id/kla_10107001_001',
#  'http://sillok.history.go.kr/id/kla_10107001_002',
#  'http://sillok.history.go.kr/id/kla_10107001_003',
#  'http://sillok.history.go.kr/id/kla_10107001_004',
#  'http://sillok.history.go.kr/id/kla_10107001_005',
#  'http://sillok.history.go.kr/id/kla_10107001_006',
#  'http://sillok.history.go.kr/id/kla_10107001_007',
#  'http://sillok.history.go.kr/id/kla_10107001_008',
#  'http://sillok.history.go.kr/id/kla_10107001_009',
#  'http://sillok.history.go.kr/id/kla_10107002_001',
#  'http://sillok.history.go.kr/id/kla_10107002_002',
#  'http://sillok.history.go.kr/id/kla_10107002_003',
#  'http://sillok.history.go.kr/id/kla_10107002_004',
#  'http://sillok.history.go.kr/id/kla_10107002_005',
#  'http://sillok.history.go.kr/id/kla_10107002_006',
#  'http://sillok.history.go.kr/id/kla_10107002_007',
#  'http://sillok.history.go.kr/id/kla_10107002_008',
#  'http://sillok.history.go.kr/id/kla_10107002_009',
#  'http://sillok.history.go.kr/id/kla_10107003_001',
#  'http://sillok.history.go.kr/id/kla_10107003_002',
#  'http://sillok.history.go.kr/id/kla_10107003_003',
#  'http://sillok.history.go.kr/id/kla_10107003_004',
#  'http://sillok.history.go.kr/id/kla_10107004_001',
#  'http://sillok.history.go.kr/id/kla_10107004_002',
#  'http://sillok.history.go.kr/id/kla_10107004_003',
#  'http://sillok.history.go.kr/id/kla_10107004_004',
#  'http://sillok.history.go.kr/id/kla_10107004_005',
#  'http://sillok.history.go.kr/id/kla_10107004_006',
#  'http://sillok.history.go.kr/id/kla_10107005_001',
#  'http://sillok.history.go.kr/id/kla_10107005_002',
#  'http://sillok.history.go.kr/id/kla_10107005_003',
#  'http://sillok.history.go.kr/id/kla_10107005_004',
#  'http://sillok.history.go.kr/id/kla_10107006_001',
#  'http://sillok.history.go.kr/id/kla_10107006_002',
#  'http://sillok.history.go.kr/id/kla_10107006_003',
#  'http://sillok.history.go.kr/id/kla_10107006_004',
#  'http://sillok.history.go.kr/id/kla_10107006_005',
#  'http://sillok.history.go.kr/id/kla_10107006_006']

# %%
all_articles = []
for url in all_urls:
    article_page = html.fromstring(requests.get(url).text)
    title = "".join(article_page.xpath('//*[@id="cont_area"]/div[1]/div[1]/h3/text()'))
    content = "".join(article_page.xpath('//*[@id="cont_area"]/div[1]/div[3]/div[1]/div/div/p//text()'))
    category = (''.join(article_page.xpath('(//span[@class="ins_source_tit"]/following-sibling::div)[1]/text()'))).split(" / ")
    all_articles.append({'url':url, 'title':title,'content':content,'category':category})

# %%
html.fromstring(requests.get(all_urls[0]).text).xpath('//*[@id="cont_area"]/div[1]/div[1]/h3/text()')
# Out:
# ['삭전을 지내고 상식을 올리다']

# %%
article_page = html.fromstring(requests.get(all_urls[0]).text)
article_page
# Out:
# <Element html at 0x1b4c06a7950>

# %%
title = article_page.xpath('//*[@id="cont_area"]/div[1]/div[1]/h3')
title
# Out:
# [<Element h3 at 0x1b4c1e00900>]

# %%
title = article_page.xpath('//*[@id="cont_area"]/div[1]/div[1]/h3/text()')
title
# Out:
# ['삭전을 지내고 상식을 올리다']

# %%
title = "".join(article_page.xpath('//*[@id="cont_area"]/div[1]/div[1]/h3/text()'))
title
# Out:
# '삭전을 지내고 상식을 올리다'

# %%
article_page.xpath('//*[@id="cont_area"]/div[1]/div[3]/div[1]/div/div/p//text()') # //의 차이
# Out:
# ['상(上)이 ',
#  '삭전(朔奠)',
#  '001)',
#  '  을 지내고 ',
#  '상식(上食)',
#  '002)',
#  '  을 올렸다.',
#  '【이에 앞서는 삭망전(朔望奠)과  ',
#  ' 별제(別祭)',
#  '003)',
#  ' 를 ',
#  '대군(大君)',
#  '004)',
#  '  이 부스럼을 앓았기 때문에 지내지 않다가 이때부터 다시 지냈다.】',
#  '\r\n\t\t\t\t\t\t\r\n\r\n\t\t\t\t\t\t\r\n\t\t\t\t\t\t']

# %%
category = (''.join(article_page.xpath('(//span[@class="ins_source_tit"]/following-sibling::div)[1]/text()'))).split(" / ")

//*[@id="cont_area"]/div[1]/div[3]/div[1]/div/div/ul[1]/li[2]/div

# %%
article_page.xpath('//*[@id="cont_area"]/div[1]/div[3]/div[1]/div/div/ul[1]/li[2]/span/text()') # 아래 두개와 교수님 XPATH와의 차이
# Out:
# ['【분류】']

# %%
article_page.xpath('//*[@id="cont_area"]/div[1]/div[3]/div[1]/div/div/ul[1]/li[2]/div/text()')
# Out:
# ['왕실(王室)']

# %%
# url 먼저 수집하고 뼈대 세운 뒤 수집??

# %%
# phantomjs # 크롬이 떴다고 치고 작업 # 따라서 시간이 적게 걸림

# %%
all_articles
# Out:
# [{'url': 'http://sillok.history.go.kr/id/kla_10101001_001',
#   'title': '삭전을 지내고 상식을 올리다',
#   'content': '상(上)이 삭전(朔奠)001)  을 지내고 상식(上食)002)  을 올렸다.【이에 앞서는 삭망전(朔望奠)과   별제(別祭)003) 를 대군(大君)004)  이 부스럼을 앓았기 때문에 지내지 않다가 이때부터 다시 지냈다.】\r\n\t\t\t\t\t\t\r\n\r\n\t\t\t\t\t\t\r\n\t\t\t\t\t\t',
#   'category': ['왕실(王室)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101001_002',
#   'title': '햇무리가 지다',
#   'content': '햇무리가 졌다.',
#   'category': ['과학-천기(天氣)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101002_001',
#   'title': '조석전을 지내고 상식을 올리다',
#   'content': '상이 조석전(朝夕奠)을 지내고 상식을 올렸다.',
#   'category': ['왕실(王室)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101002_002',
#   'title': '좌의정 홍언필이 사직을 청하다',
#   'content': ' 좌의정 홍언필(洪彦弼)이 아뢰기를,"신(臣)은 장구(章句)나 따지는 하찮은 선비로서 어쩌다가 과제(科第)에 들어서 사판(仕版)에 끼게 되었고 외람되이 여러 선비들의 반열에 끼게 된 것도 자신을 돌아봄에 이미 만족합니다. 그런데 그럭저럭 지내다가 인재가 모자란 탓으로 분수에 맞지 않는 자리를 차지하였으므로, 항상 직임을 제대로 수행하지 못할까 걱정하여 왔으나 오랫동안 자리만 지키고 있다는 기롱을 받았습니다.대행 대왕(大行大王)께서 빈천(賓天)하시어 상제(喪制)에 대해 갖출 일이 갖가지로 많았으므로 전례에 따라 참작하여 단행하더라도 응당 적격자가 있어야 했는데, 신은 그 사이에 있으면서 어리석어 아는 것이 없었습니다. 또 성상께서 처음 즉위하여 기강을 갖추고 기본을 세우실 때를 당하였으므로 신민(臣民)이 눈을 닦고 기대하는 것이 바로 오늘날에 달려 있는데, 어찌할 줄을 몰라 선후가 전도되게 함으로써 공론을 격발시켜 잘못을 지적하여 아뢰게 만들었으니 이는 모두 신이 자초한 것입니다. 따라서 스스로 반성하기에 겨를이 없어야 하는데도 오히려 낯을 들고 대궐에 나아가 간절히 사직하는 말을 여러번 아뢰었습니다. 성상께서는 신이 선조(先朝)의 신하이고 동궁(東宮)의 구료(舊僚)라 하여 위로하고 측은히 여겨 극진히 감싸주셨습니다. 변변치 못한 신으로서는 감히 감당할 수가 없어 마음에 새기고 뼈에 새겨도 우러러 보답할 방법이 없습니다.생각하건대, 도규(道揆)005)  의 직임은 만인이 우러러보고 본보기로 삼는 자리이므로 관계되는 바가 가볍지 않습니다. 조금이라도 사람들의 말이 있으면 서슴없이 파면하는 것은 그 지위를 중시하기 때문입니다. 한 가지 일을 잘못하여도 이렇게 되는 것인데, 온갖 허물과 잘못이 신의 몸에 집중되었으니 조정(朝廷)의 높은 벼슬에 끼이기 어려운 줄 알고 있습니다. 그런데 어찌 중한 직임(職任)에 그대로 두어 그 자리를 더럽힐 수 있겠습니까. 그러니 성상의 은혜가 비록 깊기는 하지만 신의 잘못은 더욱 드러나 가릴 수 없게 되어서 하찮은 이 한 몸 스스로 용납될 곳이 없게 되었습니다.시골에 있는 미천한 사람도 그 마을의 공론에 허용되지 않게 되면 또한 부끄러운 줄을 알아서 문을 닫고 허물을 살펴 전에 한 짓을 뉘우칩니다. 신은 이미 한 나라의 공론에 허용되지 않는데 감히 높은 자리를 차지한 채 붙들고 놓지 않는다면, 조정에 같이 있는 사람들만 한 무리가 되는 것을 부끄러워할 뿐 아니라 사람들도 장차 침을 뱉고 욕하며 나를 천하게 여길 것입니다. 일찍이 진신(縉紳)의 대열에 있었으면서도 도리어 시골의 미천한 사람만도 못할 수 있겠습니까. 신은 이것을 삼가 민망하게 여깁니다. 성상께서 신의 벼슬을 해면해서 허물을 알게 하여 주신다면 이 어찌 천지가 포용하는 큰 덕이 아니겠습니까. 이것이 신이 지극한 정성으로 지극히 바라는 것이니 신을 빨리 체직시켜 주소서."하니, 답하기를,"하늘이 내 몸에 호된 재앙을 내려 점괴(苫塊)006)  에 엎드려 있을 뿐 어찌할 바를 모르고 있으므로 상례(喪禮)에 관한 큰일을 모두 조정에 의지하고 있다. 이처럼 일이 많을 때에 나라의 일을 생각하지 않고 굳이 사피(辭避)하니 내 마음이 몹시 민망하다. 사피하지 말고 직에 나아가라."하고, 이어 술을 내렸다. 홍언필이 다시 아뢰었으나 윤허하지 않았다.  사신은 논한다. 상이 홍언필의 사람됨을 모르지는 않으나 처음 즉위한 때를 당하여 즉시 구신(舊臣)을 버리는 것을 어렵게 여겼으므로 답사의 내용이 이러했던 것이다. 조야(朝野)에서 이 말을 듣고 감복하여 기뻐하지 않는 이가 없었다.',
#   'category': ['왕실(王室)', '정론(政論)', '인사(人事)', '역사-사학(史學)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101002_003',
#   'title': '헌부가 중종의 시호를 빨리 정할 것과 이인현·정웅의 체직을 청하다',
#   'content': '헌부(憲府)가 아뢰기를,"의시(議謚)007)  는, 조종(祖宗) 때에는 하루에 다 의논하여 정하였는데 이번 대행 대왕(大行大王)008)  의 시호(諡號)는 여러 달이 되도록 정하지 못하였습니다. 이는 사체에 온편하지 못할 뿐만 아니라 국장(國葬)에 관한 모든 일이 이 때문에 늦어지니 빨리 의논하여 정하소서. 창원(昌原)은 사람이 많고 지역이 크므로 근면하고 재간이 있는 사람이 아니면 감당할 수 없는데, 부사(府使) 이인현(李仁賢)은 성품이 본디 유약하고 번다한 업무를 처리하는 재주가 없어 큰 곳에는 합당하지 않으니, 체직하소서. 도총부 경력(都摠府經歷) 정웅(鄭熊)은 성품이 본디 탐오스럽고 마음 쓰는 것이 간사하여 조정의 반열에 둘 수 없으니 파직시키소서."하니, 답하기를,"오래도록 시호를 정하지 못하였으므로 나도 매우 온편하지 못하게 여기고 있었는데 이제 아뢴 내용이 매우 마땅하다. 정웅은 인물이 그러하더라도 파직시키는 것은 또한 지나치지 않은가. 개정(改正)만 하라. 이인현은 아뢴 대로 하라."하였다.',
#   'category': ['왕실(王室)', '정론(政論)', '인사(人事)', '사법(司法)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101002_004',
#   'title': '이조 정랑 윤희성의 졸기',
#   'content': '정원(政院)이 아뢰기를,"이조 정랑(吏曹正郞) 윤희성(尹希聖)이 지난달 그믐날에 죽었습니다. 대행 대왕 때에는 대간(臺諫)·시종(侍從)을 지낸 자가 죽어 상(喪)을 당하면 계달했었는데, 윤희성은 전에 대간·시종을 지냈으므로 감히 아룁니다."하니, 답하기를,"이 사람은 전에 요속(僚屬)009)  이었는데 이제 그의 죽음을 들으니 매우 놀랍고도 슬프다. 전례를 살펴서 특별히 치부(致賻)하라."하였다.  사신은 논한다. 윤희성은 천성이 순후하고도 참되었고 기우(氣宇)가 침착하고도 꿋꿋하였으며, 마음은 화평하고 선(善)을 좋아하여 대인 관계에 간격이 없었다. 급제하기 전에 반중(泮中)010)  에서 의논을 제기하여 스스로 상소문을 지어 기묘사림(己卯士林)011)  의 억울함을 호소하였는데, 남곤(南袞) 등을 공박하여 ‘여우와 같은 작태로 승냥이 같은 사나운 짓을 했다. 심정(沈貞)과 이항(李沆)이 먼저 처형되고 삼흉(三凶)012)  이 이어서 뒤에 처형되니 무릇 혈기가 있는 자라면 기뻐서 춤추며 경하하지 않는 이가 없었다. 그러나 기묘년의 일로 말하면 이제까지도 몹시 마음이 아픈데 어찌 아래로 지하의 썩은 뼈에게 사정(私情)을 두어서이겠는가.’ 하였으니, 식견이 있는 사람들은 확론(確論)으로 여겼다. 처음 상소(上疏)할 것을 의논할 때에는 김주(金澍)와 같이 재중(齋中)013)  에 고하기로 약속하였으나, 윤희성이 나아가 고할 때에 김주는 나아가 고하지 않았다. 윤희성이 고하고 나와서 김주를 불러 꾸짖으니, 김주가 ‘박세희(朴世熹)와 기준(奇遵)은 모두 나의 절친(切親)인데 누가 내 말을 믿겠는가.’고 답하였다. 이에 앞서 윤희성이 김주·조희윤(趙希尹)과 명망이 같았었는데, 이때에 이르러 비로소 김주가 떨어지는 것을 알게 되었다.',
#   'category': ['왕실-사급(賜給)', '인물(人物)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101003_001',
#   'title': '조석전을 지내고 상식을 올리다',
#   'content': '상이 조석전을 지내고 상식을 올렸다.',
#   'category': ['왕실(王室)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101003_002',
#   'title': '홍언필이 다시 사직을 청하다',
#   'content': ' 좌의정 홍언필이 아뢰기를,"신의 마음을 죄다 아뢰었으므로 다시 말할 것이 없습니다. 나라의 큰일 가운데 어제 법사(法司)가 아뢴 것과 같은 것은 진실로 속히 정해야 하는 것인데, 신 때문에 즉시 의논하여 정하지 못하고 여러 달이 경과하게 되었으니, 신의 죄가 더욱 무겁습니다. 신이 직에 있을 수 없다는 뜻은 조정의 상하가 아는 것일 뿐만이 아니라 여항(閭巷)의 백성도 누구나 아는데 이토록 망설이시니 참으로 몹시 민망합니다. 빨리 체직시켜 주소서."하니, 답하기를,"나의 마음도 죄다 말하였다. 의시(議諡)하는 일을 날짜를 끌면서 정하지 못하고 지금에 이른 데 대해서는 헌부가 아뢰지 않았더라도 내 마음이 편안하지 못하다. 경(卿)은 나라의 큰일을 생각하여 사피(辭避)하는 마음을 조금 억제하고 빨리 직에 나아가라. 여러날 동안 이토록 극심하게 강력히 사피하니 내가 망극한 심정을 견디지 못하겠다."하였다. 언필이 다시 아뢰기를,"벼슬이 낮은 사람이라도 청현직(淸顯職)에 있다가 물론(物論)을 받으면 마땅히 사피해야 하는 것인데 더구나 본보기가 되는 지위에 있는 대신(大臣)이겠습니까. 보잘것 없는 신이 거듭 물론을 받았으니 신이 아무리 후안무치하더라도 어찌 감히 얼굴을 들고 의시에 참여할 수 있겠습니까. 설사 의논에 참여한다 해도 조정을 더럽히고 욕되게 할 뿐입니다. 이제 신을 체직시키고 다른 사람을 등용한다면 조정이 존엄해지고 큰 일도 하기 쉬울 것인데 위에서 번번이 직에 나아가라 이르시니 신은 참으로 몹시 민망합니다. 반복하여 생각하여도 끝내 있을 수 없으니 빨리 체직시켜 주소서."하니, 답하기를,"경의 사피하는 말이 매우 간절하기는 하나 지금 국가의 일이 여러모로 바쁘니 더욱이 동요시킬 수 없다. 내 뜻은 이미 결정되었으니 경은 다시 사피하지 말라."하였다. 언필이 세 번 아뢰었으나 윤허받지 못하고 물러갔다.',
#   'category': ['왕실(王室)', '정론(政論)', '인사(人事)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101003_003',
#   'title': '헌부가 송겸·임세무의 추고를 청하다',
#   'content': '헌부가 아뢰기를,"모든 공사(公事)014)  의 출입은 반드시 정원을 거치게 해야만이 정령(政令)을 내고 시행하는 것이 광명 정대하게 되어 거짓이 발붙일 데가 없게 되는 것입니다. 한 가지 일이라도 정원을 거치지 않고 들어가는 것이 있게 되면 간사한 길이 점차 열리게 되고 따라서 뒷날의 화(禍)가 끝이 없게 되는 것입니다. 송겸(宋㻩)·임세무(林世茂)는 망극한 때를 당하여 사사로운 부탁을 받아들여 산릉(山陵)의 각 색장(各色掌)015)  을 지나치게 많이 뽑아 적어서 틈을 타 입계하였으니, 관계되는 바가 가볍지 않음은 물론 이를 들은 사람들은 경악하고 있습니다. 정시(正始)의 처음에는 모든 일을 한결같이 바른 데에서 나오게 해야 하는 것이니, 이처럼 부정한 일이 있으면 위에서 두렵게 여기고 돌이켜 생각하여 그 조짐을 막으셔야 합니다. 그런데 앞뒤로 대간이 날마다 잇달아 논계하여도 아직 윤허를 받지 못하였으니 신들은 서운함을 견딜 수 없습니다. 송겸·임세무를 빨리 추고(推考)하여 죄를 다스리소서.승지(承旨)는 후설(喉舌)의 지위에 있으므로 왕명의 출입을 미덥게 해야만 할 것인데, 근래 승지들이 공사를 출입함에 있어 조금도 유의하지 않아서 전도되는 일이 많고 위의 뜻을 받들어 따르기만을 힘쓸 뿐 바로잡는 일은 하지 않습니다. 처음에는 정원을 거치지 않고 들어갔더라도 정원에 내려졌으면 곧 들어간 연유를 상세히 살펴서 간사한 짓을 바로잡았어야 했는데, 태연히 살피지 않고 판하(判下)에만 급급 하였으니, 잘못한 것이 매우 중합니다. 색승지(色承旨)016)  는 파면하고 도승지(都承旨)는 체직시키소서."하고, 또 정웅(鄭熊)의 일을 아뢰니, 답하기를,"송겸 등의 일은 부정한 데에 관계되는 듯하니 아뢴 바를 따라야 마땅하겠으나, 창졸간이라서 전례를 살피지 못하였을 뿐이지 어찌 다른 뜻이 있었겠는가. 송겸은 전에 중임(重任)을 받은 것을 어쩔 수 없이 교체한 것도 온편하지 못한데 또 이 일 때문에 추고하여 다스린다면 어찌 심한 일이 아니겠는가. 임세무도 중임을 맡고 있는데 이제 추고하여 다스리면 위를 위하는 의리에 어긋날 듯하니 추고하여 다스릴 것은 없다. 색승지와 도승지에 대한 일은 이미 죄다 일렀으니 파체(罷遞)할 것 없다. 정웅은 문관(文官)이니 경력에서 체직시키면 반드시 부끄러움을 알아 허물을 뉘우칠 것이다. 파면할 것 없다."하였다.',
#   'category': ['왕실(王室)', '정론(政論)', '인사(人事)', '사법-탄핵(彈劾)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101004_001',
#   'title': '조석전을 지내고 상식을 올리다',
#   'content': '상이 조석전을 지내고 상식을 올렸다.',
#   'category': ['왕실(王室)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101004_002',
#   'title': '우의정 윤인경에게 시호를 빨리 정할 것을 전교하다',
#   'content': ' 우의정 윤인경(尹仁鏡)에게 전교하기를,"의시(議諡)에 대한 일은 오래도록 거행하지 못하였으므로 내가 매우 미안하게 여기고 있다. 헌부가 빨리 의논하여 정하기를 청하였어도 아직 가부가 없으니 경은 빨리 거행해야 한다."하였다. 윤인경이 아뢰기를,"신도 염려하고 있습니다마는, 의시는 나라의 큰일인데 수상(首相)이 나오지 않아서 못하고 있습니다."하니, 대답하기를,"내일 궐정(闕庭)에 재상들을 모으고 아울러 좌상(左相)도 불러서 의논하라."하였다.',
#   'category': ['왕실(王室)', '정론-정론(政論)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101004_003',
#   'title': '간원이 승지의 체직을, 헌부가 혼전을 정할 것을 청하다',
#   'content': '간원(諫院)이 아뢰기를,"수릉관(守陵官)과 시릉관(侍陵官) 등은 망극한 일을 당한 처음에 사사로운 부탁을 받아들여 새 능(陵)의 각 차비(各差備)017)  의 숫자를 지나치게 많이 마련하여 남모르게 계하(啓下)018)  하였으므로 공론이 현저히 발론되었으니, 죄를 용서하기 어렵습니다. 이제 만약 창졸간이라고 핑계하여 죄를 다스리지 않는다면 간사한 길이 열리게 되고 따라서 말류(末流)의 폐단을 막기 어렵게 될 것이니, 빨리 추고하여 죄를 다스리소서. 정원(政院)은 후설의 지위에 있으므로 정원을 거치지 않고 까닭 없이 계하된 것을 보았으면 곧 계품하여 추고하기를 청해야 할 것인데 태만히 살피지 않았으니, 잘못한 것이 중대한 데에 관계됩니다. 색승지는 체직시키고 도승지는 추고 하소서."하였다.',
#   'category': ['왕실(王室)', '정론-간쟁(諫諍)', '인사(人事)', '사법-탄핵(彈劾)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101004_004',
#   'title': '헌부에서 창덕궁으로 옮길 것을 청하다',
#   'content': '헌부가 또 아뢰기를,"이제 자전(慈殿)께서 그대로 창경궁(昌慶宮)에 계시므로 전하께서도 거기에서 가까이 모시려 하시니 효성이 지극하십니다. 다만 창경궁은 본디 법궁(法宮)019)  이 아니기 때문에 선왕(先王)께서도 오래 머물러 계신 적이 없으므로 궐내(闕內)에서 시위(侍衛)하는 장졸(將卒)들이 입직할 곳이 없어서 춥거나 더울 때를 막론하고 한데에 서 있게 되어 그 괴로움을 견디지 못할 정도이니, 이곳은 임금이 늘 계실 곳이 못됩니다. 또 성종(成宗) 때에는 늘 창덕궁(昌德宮)에 계시면서 창경궁으로 왕래하며 대비전(大妃殿)에 문안하셨는데, 두 궁은 담 하나를 사이에 두고 있을 뿐이어서 곁에서 모시는 것과 다를 것이 없었습니다. 졸곡(卒哭)020)  이 지난 뒤에는 창덕궁으로 옮기고 문정전(文政殿)을 혼전(魂殿)021)  으로 삼으소서. 형조는 사송(詞訟)이 번다하므로 하루도 장관이 없어서는 안 되는데, 판서 남효의(南孝義)는 늙고 병들었을 뿐더러 재기(材器)도 모자라서 육조(六曹)의 장관에 맞지 않으니, 체직시키소서."하니, 답하기를,"처음에는 자전께서 창경궁에 나아가 계셨으므로 내가 가까이 모시려고 선정전(宣政殿)022)  을 혼전으로 삼으려 하였으나, 이제 아랫사람이 직숙(直宿)할 곳이 없을 뿐더러 폐단도 많이 있다 하니 아뢴 대로 하라. 송겸 등의 일에 대해서는 내 뜻을 이미 다 일렀다. 남효의는 전에 한성부의 장관을 지냈었고 형조에는 또한 참판(參判)과 참의(參議)가 있으니, 병이 있더라도 조리하면 사진(仕進)할 수 있을 것이다. 체직할 것은 없다."하였다.',
#   'category': ['왕실(王室)', '정론-간쟁(諫諍)', '인사(人事)', '사법(司法)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101005_001',
#   'title': '조석전을 지내고 상식을 올리다',
#   'content': '상이 조석전(朝夕奠)을 지내고 상식(上食)을 올렸다.',
#   'category': ['왕실(王室)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101005_002',
#   'title': '우의정 윤인경 등이 의논하여 시호를 정하다',
#   'content': ' 우의정 윤인경(尹仁鏡), 좌찬성 이기(李芑), 우찬성 성세창(成世昌), 이조 판서 신광한(申光漢), 호조 판서 임백령(林百齡), 예조 판서 임권(任權), 병조 판서 정옥형(丁玉亨), 공조 판서 유인숙(柳仁淑), 호조 참판 심연원(沈連源), 예조 참판 정만종(鄭萬鍾), 병조 참판 신영(申瑛), 형조 참판 윤개(尹漑), 공조 참판 강현(姜顯), 동지중추부사 정순붕(鄭順朋)이 명을 받고 예궐(詣闕)하였다. 윤인경이 아뢰기를,"의시(議諡)하는 일 때문에 신들이 모두 와서 모였습니다마는 좌의정 홍언필(洪彦弼)이 병으로 오지 않았는데 어찌해야 하겠습니까?"하니, 답하기를,"내 생각에는 의시는 나라의 큰일이므로 복상(卜相)023)  하여 삼공(三公)을 갖춘 뒤에 의논하여 정하려 하였으나 그렇게 하면 일이 점점 늦어지겠으므로 경들을 시켜 오늘 모여서 의논하게 한 것이다. 좌의정은 병이 있어서 오지 않았더라도 조정(朝廷)이 이제 다 모였으니 경은 의논하라."하였다. 그래서 함께 의논하여 시호(諡號)를 휘문 소무 흠인 성효(徽文昭武欽仁誠孝)로, 묘호(廟號)를 중종(中宗)으로, 능호(陵號)를 희(禧)로, 전호(殿號)를 영경(永慶)으로 정하고, 윤인경 등이 아뢰기를,"폐조(廢朝)024)  의 혼란하던 때를 당하여 백성이 도탄에 빠지고 종사(宗社)025)  가 거의 위태롭게 되었을 적에 대행 대왕(大行大王)께서 중흥하여 종사를 다시 편안하게 하였으므로 중종으로 하였으며, 능호는 조종(祖宗) 때에도 그대로 썼으므로 고치지 않았습니다."026)    하니, 알았다고 전교하였다.  사신은 논한다. 의시할 때에 윤인경이 ‘좌의정 홍언필과 의논하였더니 인(仁)자를 쓰려고 했다.’ 하니, 성세창이 ‘인자도 마땅할 듯하나 종사를 다시 편안하게 하였으니 효(孝)자를 쓰는 것이 마땅할 듯하다.’ 하고, 정순붕·신광한·임권은 ‘폐주(廢主)가 혼란하여 국가가 거의 망하여 장차 역성(易姓)의 화(禍)027)  가 있을 지경에 이르렀는데 들어와서 대통(大統)을 이어 종사가 다시 편안하게 하였으니, 강(康)자를 써야 마땅하다.’ 하고, 성세창은 ‘성왕(成王) 뒤에 강왕(康王)028)  이 있었는데 대행 대왕께서도 세대를 이은 임금이시므로 강(康)자는 마땅할 듯하나 인(仁)자로 말하면 미안할 듯하다. 전에 들으니 성종(成宗)의 의시 때에도 인자를 쓰려 하였으나 당시의 의논이 지나친 듯하다 하여 마침내 쓰지 않았다 한다.’ 하고, 신광한은 ‘한 선제(漢宣帝)가 창읍왕(昌邑王)029)  을 폐출(廢黜)하고 들어가 대통을 이은 것을 당시에 증흥이라 일컬었는데 이번 대행 대왕의 사적(事迹)도 선제와 비슷하니 이제 먼저 중흥인지의 여부를 정하고 나서 의시하는 것이 옳겠다.’ 하였다. 이리하여 의논이 마침내 정해진 것이다.',
#   'category': ['왕실(王室)', '정론-정론(政論)', '역사-사학(史學)', '역사-고사(故事)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101005_003',
#   'title': '대간과 헌부가 송겸·임세무·승지 등과 남효의의 일을 아뢰다',
#   'content': '대간이 송겸·임세무·승지 등의 일을 아뢰고, 헌부가 남효의의 일을 아뢰니, 답하였다."다 아뢴 대로 하라. 다만 임세무와 도승지는 행공 추고(行公推考)030)  하라."',
#   'category': ['왕실(王室)', '정론-간쟁(諫諍)', '사법-탄핵(彈劾)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101005_004',
#   'title': '부제학 송세형 등이 올린 간관의 역할 등에 관한 차자',
#   'content': ' 부제학(副提學) 송세형(宋世珩) 등이 차자(箚子)를 올리기를,"지극히 광대한 일과 지극히 중요한 기틀에 대하여는 아무리 명철한 군주일지라도 생각이 잘못되는 것을 면하지 못하는 것이 있는데 한번 잘못되면 그 해가 매우 큽니다. 그래서 반드시 충량(忠良)한 선비를 두어 이들로 귀를 삼고 눈을 삼아 잘못을 바로잡고 부족한 것을 보충해서 허물이 없게 해야 하는 것입니다. 이 때문에 간언(諫言)을 따르면 사리에 밝아지고 간언을 물리치면 사리에 어두워지는 것인데, 사리에 밝으면 군자가 마음을 다 바치게 되고 사리에 어두우면 소인이 속일 수 있게 되는 것입니다. 이런 기틀의 변이는 그 사이가 터럭도 용납할 수 없을 만큼 긴한 것인데, 다만 듣기에는 씁쓸하지만 일에는 유익한 말은 받아들이기가 어려운 점이 있으므로 물리친들 무엇이 해로우냐고 하며 도리에 맞추어 보지 않음에 따라, 스스로를 훌륭하게 여기는 기색이 나타나게 되고 남의 의견을 돌아보지 않는 마음이 자라나게 되는 것입니다. 그리하여 직언(直言)은 구중(九重)에서 멀어지고 정사(正士)는 천리 밖에서 그치므로 나랏일이 날로 잘못되어가도 감히 바로잡을 사람이 없어 마침내 위망(危亡)에 이르러도 구제할 수 없게 되니, 두려워하지 않을 수 있겠습니까.전하께서는 선대의 업을 이으신 처음이므로 일마다 한결같이 광명하고 정대한 데에서 나와서 정시(正始)의 도리를 다하여 성덕(聖德)에 누를 끼치는 일이 없게 하셔야 할 것입니다. 그런데 대간이 말하는 것이 있으면 번번이 전례를 핑계삼고 의에 어긋난 것을 인유(引喩)하는 등 구차하게 구습을 따르려는 마음이 많고 물 흐르듯 간언(諫言)을 받아들이는 아름다움은 없으시니, 신들은 실망을 금할 수 없습니다.도거(刀鋸)를 받은 천한 자031)  는 명령을 전하는 일에 대비하기 위한 것인데, 등덩굴 같은 성질에 성사(城社)032)  를 터전으로 삼으므로 한번 일을 맡기면 곧 부정한 마음을 먹고 처음에는 작은 일로 요구하다가 큰 일로 이어가고 작은 계책으로 대략 시험하다가 비밀스런 계책으로 이어 갑니다. 때문에 임금이 기미를 통촉하여 작을 때에 도모하지 않고 조금이라도 용서하는 경우에는 자신도 모르는 사이에 그들의 수중에 빠져 점점 간사한 길을 열어주게 됨은 물론 집안을 바루는 도리를 잃고 나라를 망치는 화(禍)를 가져오게 되는데, 한(漢)·당(唐) 때의 일이 귀감입니다.요즈음 갑자기 황급한 일을 당한 것을 이용하여 시릉(侍陵)의 직임을 받은 것을 가탁, 문득 법을 무시하는 간사를 부려 몰래 계자(啓字)를 찍어 정원에 내렸는데, 전하께서는 바야흐로 상중(喪中)에 계시니 어떻게 이것을 아실 수 있겠습니까. 대간이 그 정상을 발각하여 논집(論執)한 데 이르러서는 마땅히 놀라고 두려운 마음으로 끝까지 따져서 엄히 다스리셔야 할 것인데도 도리어 부당하게 용서하고 실수로 돌리시니, 신들은 전하의 뜻이 어떠한지를 모르겠습니다. 전하의 성명(聖明)으로 결코 이들의 터전을 만들어 주시지는 않겠지만 이미 그 일을 개정하게 하셨습니다. 음흉한 정상을 모르시지 않을 것인데도 오히려 그 죄를 다스리도록 허가하시지 않으니 국가의 대계(大計)는 생각하시지 않는 것입니까. 전하께서는 옛부터 근습(近習)의 환란이 늘 미세한 데에서 일어난 것을 아시지 않습니까. 신들은 이 환시들을 다스리지 않으면 왕법(王法)을 보일 수 없다고 생각합니다. 전(傳)에 ‘터럭만한 차이가 나중에는 천리나 빗나가게 된다.’고 하였는데, 더구나 어긋난 것이 터럭만한 정도가 아닌데 이겠습니까. 신들은 한심스러움을 견디지 못하겠습니다.보필하는 신하는 임금과 천위(天位)를 함께 하여 천직(天職)을 보살피는 것이 임무이므로 그 책임이 이미 무거우니 거취(去就) 또한 구차하여서는 안 됩니다. 요즈음 대신이 중한 물론(物論)을 받았으므로 여러날 동안 사직하면서 반드시 체직되기를 바라는데도 전하께서는 구신(舊臣)을 체직시키지 않으려고 곧 윤허하시지 않으셨으니 그 뜻은 후합니다. 그러나 고식적으로 시일을 끌면서 대신의 거취를 구차스럽게 만드는 것은 더욱 대신을 존중하는 뜻이 아닙니다. 더구나 양암(諒闇)033)   중이고 처음 즉위하시어 국가에 일이 많은 때를 당하여 대신의 직임은 온갖 책임이 집중되어 있는 것인데 어찌 하루인들 그 자리를 비워둘 수 있겠습니까. 전하께서는 힘써 공론을 따라 빨리 조처하소서."하니, 답하기를,"시릉관(侍陵官)은 이미 추고하게 하였다. 좌상은 차마 체직시킬 수 없다."하였다.',
#   'category': ['왕실(王室)', '정론-간쟁(諫諍)', '인사(人事)', '사법(司法)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101006_001',
#   'title': '조석전을 지내고 상식을 올리다',
#   'content': '상이 조석전(朝夕奠)을 지내고 상식(上食)을 올렸다.',
#   'category': ['왕실(王室)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101006_002',
#   'title': '시호를 중조로 고치는 것에 관해 전교하다',
#   'content': ' 우의정 윤인경(尹仁鏡), 좌찬성 이기(李芑), 우찬성 성세창(成世昌), 좌참찬 권벌(權橃), 병조 판서 정옥형(丁玉亨), 예조 판서 임권(任權), 호조 판서 임백령(林百齡), 예조 참판 정만종(鄭萬鍾), 병조 참판 신영(申瑛), 형조 참판 윤개(尹漑), 공조 참판 강현(姜顯), 동지중추부사 정순붕(鄭順朋)이 명을 받고 예궐하니, 전교하기를,"대행 대왕의 묘호를 보고 내 생각에도, 상사(商史)에 은(殷)나라의 도를 부흥시겼으므로 중종(中宗)이라 호칭하였다는 말이 있다 하여 조정이 이에 의거하여 한 것으로 여겼기 때문에 이미 계하(啓下)하였다. 그러나 이제 다시 생각하건대 부왕(父王)께서 폐조의 혼란한 때를 당하여 어지러운 것을 다스려 반정(反正)하고 종사를 40년 동안 또 편안하게 하셨으니, 중흥시킨 공이 작다 할 수 없다. 그래서 조(祖)라 칭하고자 하는데 첨의(僉意)034)  가 어떠한가? 중(中)자가 중흥의 뜻이라고는 하나 또한 흡족하지 못한 듯하니, 세조(世祖)의 예(例)에 견주어 종(宗)자를 고치고자 한다."하였다. 윤인경 등이 의논하여 아뢰기를,"신들이 다시 함께 상의하였으나, 조(祖)자 위에는 달리 알맞은 글자가 없고 세(世)자가 있을 뿐인데 이미 세조의 묘호가 있으니 합당한 자가 전혀 없습니다. 또 역대의 임금 중에 특별히 조자로 칭한 경우가 없으며 조는 공이 있는 것이고 종은 덕이 있는 것이니, 종자가 어찌 범연한 것이겠습니까. 위에서도 《상서(尙書)》 무일편(無逸篇)에서 보신 바와 같이 은 중종(殷中宗)의 일이 바로 대행 대왕의 일과 서로 같았기 때문에 이 호를 의논해 올린 것입니다."하고, 이어서 무일편의 은 중종에 대한 일에 부표(付標)하여 아뢰었다. 또 아뢰기를,"졸곡(卒哭)뒤에 백립(白笠)을 쓰는 일에 대해서는 이제 육조(六曹)와 함께 회의하는 것이 어떠하겠습니까?"하니, 대답하기를,"조는 공이 있고 종은 덕이 있는 것이라는 말이 있기는 하나, 부왕께서는 공과 덕을 다 갖춘 가운데에서도 그 공이 크시니 은 중종과 덕은 서로 같을지라도 공은 현격히 다르다. 어찌하여 조자 위에 알맞은 자가 없다 하는가. 나는 조호(祖號)로 칭하여 올리기를 절실히 바라고 있다. 그리고 백립에 대한 일은 아뢴 대로 하라."하였다. 윤인경 등이 회계(回啓)하기를,"남송 고종(南宋高宗)의 호를 정할 때 홍매(洪邁)가 조로 칭하고자 하였으나 우무(尤袤)가 ‘한 광무(漢光武)는 장사정왕(長沙定王)035)  의 후손으로서 들어가 대통(大統)을 이었으므로 조로 칭하였으나, 고종은 중흥하였어도 휘종(徽宗)의 아들로서 바로 대통을 이어받았으므로 조로 칭할 것은 없다.’ 하여 마침내 고종이라 칭하게 된 것입니다. 신들이 상의 분부를 다시 받고 반복하여 생각하여 보았습니다만, 세조를 조로 칭한 것은 아우로서 형을 이었기 때문인데 대행 대왕께서는 중흥하였어도 바로 성종(成宗)의 계통을 이었으니 조로 칭하는 것은 온당하지 못하겠습니다."하고, 인경이 또 이기·성세창·권벌·정순붕·정옥형·임권·임백령과 함께 백립에 대한 일을 의논하여 아뢰기를,"전에 성묘(成廟)036)  때 정희 왕후(貞熹王后)의 상(喪)을 당하여 신하를 모아 이 일에 대해 의논하였습니다. 그때 서거정(徐居正)·이파(李坡)·유순(柳洵)·김종직(金宗直)·정성근(鄭誠謹) 같은 무리는 다 한때의 이름 있는 선비였는데, 그들의 의논이 다 흑립(黑笠)을 따랐으므로 성종께서 또 정례(情禮)를 참작하여 전지(傳旨)를 내리셨습니다. 신들의 생각으로는 선왕 때에 이미 정해진 제도를 이제 와서 고칠 수 없으니 흑립을 쓰는 것이 마땅하다고 여깁니다."하고, 이어 성종 때의 의득(議得)과 전지를 써서 아뢰었다. 강현·정만종·윤개·심연원(沈連源)·신영은 의논하여 아뢰기를,"예문(禮文)에 ‘졸곡 뒤에 갓[笠]은 흰 것을 쓴다.’ 한 데에는 반드시 의거한 것이 있을 것인데 이렇게 만든 뜻을 구명하지 않고 경솔히 고쳐 정한 것은 관계된 바가 매우 중한 일입니다. 성묘 때에 한때의 의논에 따라 고쳤다 하더라도 그때의 전교에 ‘경솔히 감쇄(減殺)하여 흉(凶)을 바꾸어 길(吉)을 따르는 것은 마음에 미안하다.’고 하셨으니, 이것으로도 성묘의 본의가 아니었다는 것을 알 수 있습니다. 더구나 위에서는 익선관(翼善冠)에 오서대(烏犀帶)를 하고 아래에서는 오사모(烏紗帽)에 흑각대(黑角帶)를 하는 것은 오로지 신하들에게 임하여 함께 관사(官事)를 처리함에 있어 순흉(純凶)으로 할 수 없기 때문인 것입니다. 한가하게 사사로이 있을 때에도 백립을 벗는다면, 선왕의 제례(制禮)를 어길 뿐더러 참으로 대상(大喪)의 정문(情文)에도 맞지 않는 데가 있을 듯합니다."하니, 대답하기를,"부왕께서는 성종의 계통을 이으셨다 해도 그 사이에 폐왕(廢王)037)  이 재위하였으므로 세조와 문종(文宗) 사이에 노산(魯山)038)  이 재위한 일과 서로 다르지 않을 듯한데, 어찌하여 유독 조호(祖號)를 칭해 올릴 수 없단 말인가? 또 송 고종의 일과는 견주어 논할 수 없으니 내 뜻을 따르기 바란다. 그리고 백립에 대한 일은, 성종께서 전교하신 뜻이 우상(右相) 등의 뜻과 서로 맞기는 하나 참판 등의 뜻도 예문과 맞는다. 상제(喪制)의 대례(大禮)는 경솔히 정하기 어려울 듯하니, 내일 성종 때의 전례에 따라 대간·홍문관이 함께 의논하게 하라."하였다.',
#   'category': ['왕실(王室)', '정론-정론(政論)', '의생활(衣生活)', '역사-고사(故事)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101006_003',
#   'title': '윤인경이 중국 사신의 원접사 문제를 아뢰다',
#   'content': ' 윤인경이 아뢰기를,"중국 사신을 지대(支待)하는 일은, 원접사(遠接使)와 관반(館伴)을 차출한 뒤에야 모든 일을 맡아 처리할 수 있는 것입니다. 그런데 원접사는 대제학(大提學) 성세창(成世昌)이 당연히 맡아야 하지만 관반은 이조로 하여금 차출하게 하는 것이 어떠하겠습니까?"하니, 아뢴 대로 하라고 답하였다.',
#   'category': ['인사(人事)', '외교-명(明)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101007_001',
#   'title': '조석전을 지내고 상식을 올리다',
#   'content': '상이 조석전을 지내고 상식을 올렸다.',
#   'category': ['왕실(王室)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101007_002',
#   'title': '대사간 임억령, 집의 한두 등이 대간의 임무에 대해 아뢰다',
#   'content': '        대사간        임억령(林億齡), 집의        한두(韓㞳), 사간        한주(韓澍), 장령        권물(權勿), 지평        이천계(李天啓)·이담(李湛), 헌납        성세장(成世章), 정언        조광옥(趙光玉)·김난상(金鸞祥)이 명을 받고 와서 아뢰기를,"무릇 국가의 일에 대해 조정이 의논하여 정한 데에 잘못된 것이 있으면 대간이 바로잡는 것입니다. 이번 흑립과 백립에 관한 의논에 대간도 함께 참여하라고 전교하셨는데, 대간이 참여한다면 잘못된 것이 있을 경우 누가 바로잡을 수 있겠습니까? 함께 참여하지 말게 하소서."하니, 답하기를,"성묘 때에 대간과 홍문관이 이 일을 같이 의논하였기 때문에 말한 것이다. 어제 참판 등의 의논이 《오례의(五禮儀)》와 서로 맞고 나도 백립으로 하기를 바라고 있으나 물론이 일치되지 않는다. 그래서 널리 의논하도록 명한 것인데, 이는 바로잡기를 기다리지 않고 바른 데로 돌아가게 하려는 것이다. 의논하여 아뢰도록 하라."하였다. 임억령 등이 다시 아뢰기를,"대간의 직무는 시비를 바로잡는 것일 뿐이므로 조정의 의득(議得)에 참여할 수 없습니다. 전에 혹 의논에 참여한 때가 있다 해도 그 전례가 이미 잘못된 것이니 이 일을 원용하여 상례(常例)로 삼을 수는 없습니다. 반복하여 생각하여 보아도 직분을 넘어서 논의하는 것은 사체에 크게 해로운 것이기에 감히 아룁니다."하니, 답하기를,"홍문관이 의주(儀註)039)                  를 따를 것을 의논해 아뢰었고          【아래에 보인다.】         내 생각에도 반드시 백립을 써야 할 듯하니 대간은 의논할 것 없다."하였다.                  사신은 논한다. 위에서 예(禮)를 좋아하는 것이 매우 독실해서 공경(公卿)의 구차하고 간략한 의논을 따르지 않고 신충(宸衷)으로 결단하여 3년 동안 백립을 쓸 것으로 제도를 정하였으니, 후세에 모범이 될 만하다.',
#   'category': ['정론-간쟁(諫諍)', '행정-중앙행정(中央行政)', '의생활(衣生活)', '역사-사학(史學)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101007_003',
#   'title': '홍문관 부제학 송세형 등이 졸곡 후의 복제에 대해 아뢰다',
#   'content': '홍문관 부제학 송세형(宋世珩) 등이 의논하여 아뢰기를,"졸곡 뒤에 위에서는 익선관에 오서대를 하고 신하들은 오관(烏冠)에 오대(烏帶)를 쓰는 것은 조회에서 일을 처리하기 위하여 어쩔 수 없이 권제(權制)를 쓴 것으로 순전히 길복(吉服)을 쓸 수 없었기 때문입니다. 상례(喪禮)에 관한 모든 일에 있어 최복(衰服)040)  을 입는다면 최마(衰麻)가 오히려 몸에 있는 것인데, 유독 사사로이 있을 때에는 상제(喪制)를 죄다 버리고 갓을 검게 한다는 것은 이치에 맞지 않을 듯합니다. 조종 때에는 다 백립을 썼는데 성종 때에 한때의 의논에 따라 비로소 옛 제도를 바꾸었으나 오히려 ‘흉을 바꾸어 길을 따르는 것은 마음에 미안하다.’는 분부가 계셨으니, 성묘의 뜻도 알 수 있습니다. 주자(朱子)가 ‘임금이 상중(喪中)에 있으면서 백포(白布)로 된 의관(衣冠)으로 조정에 임하여도 안 될 것은 없다.’고 하였습니다. 조정에 임하여 신하들을 볼 때에도 백포의 의관을 쓸 수 있는데, 더구나 한가히 있을 때에 오로지 길복을 쓰는 것이겠습니까. 임금도 그러한데 더구나 신하들이겠습니까. 누구나 삼년상을 입는 것은 하늘의 도리이고 땅의 의리이므로 사사로운 뜻으로 증감하는 것은 있을 수 없습니다. 《오례의》는 우리 나라의 열성(列聖)들께서 고금의 예절을 참작하여 만세에 항상 행할 제도를 제정한 것이니, 후사(後嗣)로서는 당연히 준수해야 하는 것이요 고쳐서는 안 되는 것입니다. 이제 구차히 근래의 전례를 따라 반드시 다시 그르치려 하니 매우 온편하지 못합니다.지금 우리 나라의 풍속은 늘 흰옷을 입는 것이 조종 때보다 더한데, 갓까지 검게 한다면 여느 때와 조금도 다를 것이 없으니 신들은 슬픔도 따라서 없어지고 예의도 따라서 무너질까 염려됩니다. 신들의 생각으로는 군부를 위한 큰 복제(服制)는 결코 흉을 바꾸어 길을 따르고 후한 것을 버리고 박한 것을 따를 수 없다고 여겨지니, 한결같이 《오례의》에 따라서 거행하소서."하니, 답하기를,"내 뜻도 그러하니 《오례의》를 따르도록 하라."하였다.',
#   'category': ['왕실(王室)', '정론(政論)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101007_004',
#   'title': '우의정 윤인경 등이 시호를 중조로 하는 것이 부당하다고 아뢰다',
#   'content': ' 우의정 윤인경(尹仁鏡) 등이 【의시(議諡)한 재상이 다 모였다.】  아뢰기를,"폐조 때에 종사(宗社)가 간발의 위태로움에 있었는데 온 나라의 신민(臣民)이 대행 대왕을 추대하여 성묘의 계통을 잇게 되었으니, 중흥의 덕이 막대하였습니다. 그러니 조정이 범연하게 의논하여 중종(中宗)이라는 호를 올린 것이 아닙니다. 대저 의시는 큰 일이므로 조정이 이미 의논하여 정하였으면 고칠 수 없는 것입니다. 또 어제 세조께서 노산을 잇고 대행 대왕께서 폐왕을 이으셨다는 뜻으로 전교하셨습니다만, 노산과 폐왕은 모두 도리를 잃은 임금이므로 강봉(降封)하여 군(君)이라 칭하였으니 대를 이을 수가 없습니다. 대행 대왕께서는 성종을 승습(承襲)하여 즉위하셨으니 조(祖)로 칭하는 것은 부당합니다. 그러므로 감히 아룁니다."하니, 답하기를,"내 생각에는 부왕께서 중흥한 공이 있으므로 조호(祖號)로 칭하고자 하였다. 그러나 다시 생각하니 성묘의 계통을 이어받으신 것이다. 다시 의논할 것 없다."하였다.',
#   'category': ['왕실(王室)', '정론-정론(政論)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101007_005',
#   'title': '좌의정 홍언필의 사직서를 정원에 내리면서 사직하지 말라고 이르다',
#   'content': ' 좌의정 홍언필(洪彦弼)의 사장(辭狀)을 정원에 내리고, 또 작은 종이에 쓴 글을 내리면서 이르기를,"사관(史官)041)  에게 부쳐 좌상에게 보이라. 그리고 내의(內醫)를 보내어 진찰한 다음 약을 내리고 조리하게 하라."하였는데, 그 작은 종이의 글에 이르기를,"경에게 병이 있다면 마땅히 조리해야 할 것이요 반드시 해직(解職)해야 될 것은 없다. 한때의 논란 때문에 경솔히 대신을 바꾸는 것이 어찌 나를 위해 아름다운 일이겠스며 일신에 대한 비방을 피하여 스스로를 위한 계책을 도모하는 것이 또한 어찌 대신의 도리이겠는가. 아무리 일신을 돌보아야 한다지만 유독 나라의 일만을 생각하지 않을 수 있겠는가. 비록 부덕한 나는 버리고자 할지라도 또한 선조(先朝)를 생각하지 않을 수 있겠는가. 내가 불민할지라도 단연코 경의 사퇴를 받아들여 부왕의 신하를 바꾸지 않을 것이니 빨리 조리하고 나와서 스스로 큰일에 진력(盡力)해야 한다."하였다.  【사장의 내용은 다음과 같다."신은 어리석고 무식한데도 외람되어 중요한 지위에 있으니 생각이 어두워서 잘못하는 일이 많습니다. 대간이 신의 허물을 논한 것이 매우 중하므로 신이 여러날 해면(解免)해 줄 것을 청하였으나 윤허받지 못하였는데, 이제 또 시종(侍從)이 차자를 올려 공론을 따르기를 청하였다고 합니다. 신의 벼슬이 해면되지 않아서 물론이 더욱 격렬해지니 더욱 답답하기 그지없습니다. 그리고 신의 오랜 병이 심하게 더쳐서 심열(心熱)과 하냉(下冷)에 산기(疝氣)까지 극심하여 온몸의 혈기가 날마다 점점 말라가고 있습니다. 이병의 근원이 깊다는 것은 사람들이 다함께 아는 사실로 두어 달에 고칠 수 있는 것이 아닌데, 나이도 70이므로 쇠모가 더욱 심하여 죽음이 가까왔습니다. 빨리 신의 벼슬을 해면함으로써 한편으로는 허물을 알게 하고 한편으로는 병을 고치게 하여 특별히 다시 살리는 은혜를 내려 주소서."】\r\n\t\t\t\t\t\t\r\n\r\n\t\t\t\t\t\t\r\n\t\t\t\t\t\t',
#   'category': ['왕실(王室)', '인사(人事)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101007_006',
#   'title': '햇무리가 지다',
#   'content': '햇무리가 졌다.',
#   'category': ['과학-천기(天氣)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101008_001',
#   'title': '조석전을 지내고 상식을 올리다',
#   'content': '상이 조석전을 지내고 상식을 올렸다.',
#   'category': ['왕실(王室)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101008_002',
#   'title': '장령 권물, 지평 이천계·이담이 체직시켜 줄 것을 청하다',
#   'content': ' 장령 권물, 지평 이천계·이담 【장령 곽순(郭珣)은 병을 앓고 대사헌 이해(李瀣)는 아직   숙배(肅拜)042) 하지 않았다.】 이 아뢰기를,"좌의정 홍언필은 정승 자리에 합당하지 않아서 공론이 드러나게 발론되었습니다. 그리하여 대간이 논계하였는데 아직 윤허받지 못한 채 홍언필이 스스로 해결한 것으로 핑계하고는 곧 정계(停啓)하였으므로 물론이 더욱 울분해 하고 있습니다. 신들은 본직(本職)에 제수된 즉시 곧 다시 아뢰었어야 했는데도 다시 아뢰지 않았을 뿐더러 서로 용납하여 물론이 비난하고 있으니 사세가 직에 있을 수 없습니다. 신들을 체직시켜 주소서."하니, 답하기를,"대신의 일에 대해 그때의 대간이 어찌 범연하게 생각하여 정계하였겠는가. 이미 정계하였으니 이제 굳이 논집할 것은 없다. 또 서로 용납한들 무엇이 해롭겠는가. 사퇴하지 말라."하였다. 권물 등이 다시 아뢰었으나 윤허하지 않자 물러가면서 아뢰기를,"물론을 기다리겠습니다."하였다.',
#   'category': ['정론-간쟁(諫諍)', '인사(人事)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101008_003',
#   'title': '대사헌 이해가 체직을 청하다',
#   'content': ' 대사헌 이해(李瀣)가 아뢰기를,"전일 대간이 좌의정 홍언필은 정승 자리에 맞지 않는다는 것으로 논계하였다가 오래지 않아 갑자기 그쳤고, 뒤의 대관(臺官)도 곧 다시 아뢰지 않고 있다가 물론이 있다 하여 장령 이하가 인피(引避)하고 물러갔습니다. 제수된 뒤에 곧 의논하여 아뢰지 못하였더라도 이제부터 다시 아뢰면 안 될 것이 뭐가 있기에 갑자기 인피한단 말입니까. 명초(命招)043)  하여 직에 나아가게 하소서. 다만 의논이 이미 발론되었는데도 그때의 집의(執義) 한두(韓㞳)가 아직 본직에 있어 서로 용납할 수 없으니, 체직시키소서. 또 대간은 일체(一體)이니 간원도 아울러 체직시키소서."하니, 답하기를,"권물 등을 직에 나아가게 하는 일은 아뢴 대로 하라. 집의와 간원이 어찌 범연하게 생각하여 정계하였겠는가. 내 생각에는 서로 용납하여도 무방할 것 같다."하였다.',
#   'category': ['정론-간쟁(諫諍)', '인사(人事)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101008_004',
#   'title': '장령 권물 등이 직무에 나아가다',
#   'content': ' 장령 권물 등이 명을 받고 직에 나아갔다.',
#   'category': ['인사(人事)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101008_005',
#   'title': '하얀 기운이 하늘에 퍼지다',
#   'content': '백기(白氣)가 하늘에 펴져 동서로 가로 뻗쳤다.',
#   'category': ['과학-천기(天氣)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101009_001',
#   'title': '조석전을 지내고 상식을 올리다',
#   'content': '상이 조석전을 지내고 상식을 올렸다.',
#   'category': ['왕실(王室)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101009_002',
#   'title': '장령 곽순 등이 대사간 임억령 등의 체직을 청하다',
#   'content': ' 장령 곽순(郭珣)·권물, 지평 이천계·이담이 아뢰기를,"대신이 그 자리에 맞지 않아서 공론이 드러나게 발론되었으면 대간은 굳게 간쟁하여 반드시 임금의 마음을 돌려야 하는 것이요 구차하게 정론(停論)하여 대신이 스스로 해결하기를 기다려서는 안됩니다. 대사간 임덕령, 집의 한두, 사간 한주, 헌납 성세장, 정언 조광옥은 홍언필이 정승 자리에 맞지 않는 것을 이미 알고 그의 잘못을 두루 지적하였는데, 논계한 지 오래지 않아 문득 ‘대간이 정계하더라도 대신이 끝내 자리에 있을 수 없을 것이다.’고 여겨 구차하게 정계하였으니 대간의 체모를 크게 잃었습니다. 이미 공론이 발론되었으므로 형세가 직에 있을 수 없으니 모두 체차(遞差)하소서."하니, 답하기를,"집의는 같은 관사(官司)의 관원이어서 서로 용납하지 못할 듯하여 체직시켰다. 대간이 일체이기는 하지만 간원까지 아울러 체직할 것은 없다."하였다. 곽순 등이 다시 아뢰기를,"대간은 임금의 이목(耳目)이므로 그 임무가 지극히 중하여 한번 물론을 입으면 잠시도 자리에 있을 수 없는 것인데, 임억령 등은 잘못한 것이 매우 커서 무거운 물론을 입었으니 결코 그 직에 그대로 있을 수 없습니다. 대간은 여느 사람의 예와 같은 것이 아닌데 여러 차례 논계하였어도 아직 망설이고 계시니 대간을 중하게 여기는 뜻이 아주 없어 매우 온편하지 못합니다. 집의를 이미 체직하라고 명하셨으니 간원도 아울러 체직시키소서. 또 홍언필은 정승 자리에 맞지 않아서 물론이 제기된지 이미 오래고 요즈음에는 중한 논박을 드러나게 입었으니 하루도 자리에 있을 수 없는데, 더구나 지금은 국가에 일이 많을 때이어서 정승 자리를 더욱 오래 비워둘 수 없습니다. 빨리 체직시키소서."하니, 답하기를,"그때 대간이 정계한 뜻에 대해서는 내가 그것이 그른 줄을 모르겠다. 체직하지 않은 까닭은 언관(言官)을 중히 여겼기 때문이었다. 또 국가에 일이 많은 때에는 구신(舊臣)을 요동할 수 없는 것이니 전일 논집하던 때에도 어찌 범연하게 생각하여 따르지 않았겠는가. 윤허하지 않는다."하였다. 곽순 등이 또 아뢰기를,"대간은 일체인데 한 가지 일의 잘못으로 집의 한두가 이미 체직되었으니 간관(諫官)이 어떻게 직에 있을 수 있겠습니까. 망설이지 마소서. 대신이 논박받으면 직에 있을 수 없다는 뜻을 위에서 모르시지는 않을 터인데도 대신을 존중하는 뜻과 또 선조(先朝)의 구신이라는 것으로 차마 가볍게 체직하지 못하시니, 성덕(聖德)이 지극하긴 합니다. 그러나 국가의 안위와 백성의 고락이 모두 정승에게 달려 있으니 하루라도 적격자가 아닌 사람에게는 맡길 수가 없습니다. 언필은 본디 공보(公輔)의 명망이 없어서 선조 때부터 물론이 있어 왔는데 이제 국가의 큰일을 당하여 멍청히 어쩔 줄 몰라 전도된 일이 많았고 또 큰일을 논의할 때에 결단력없이 남의 뜻에만 순종하여 임금을 도리에 어긋난 데로 인도하여 신정(新政)에 큰 누를 끼쳤으니, 조정이 이 사람을 그 자리에 있도록 허용할 수는 없습니다. 홍언필도 어찌 뻔뻔스레 무릅쓰고 있을 수 있겠습니까. 신들이 범연하게 의논해 아뢴 것이 아니라 공론이 발론된 지 오래이고 갈수록 더욱 격렬해지므로 체직시키지 않을 수 없으니, 망설이지 마소서."하니, 답하기를,"체직하지 않겠다는 뜻을 이미 다 일렀다."하였다.',
#   'category': ['정론-간쟁(諫諍)', '인사(人事)', '사법-탄핵(彈劾)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101009_003',
#   'title': '정순붕·송기수·경혼 등에게 관직을 제수하다',
#   'content': ' 정순붕(鄭順朋)을 형조 판서로, 송기수(宋麒壽)를 승정원 좌부승지로, 경혼(慶渾)을 사헌부 집의로 삼았다.',
#   'category': ['인사-임면(任免)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101009_004',
#   'title': '햇무리가 지다',
#   'content': '햇무리가 지고 양이(兩珥)044)  와 관(冠)이 있었다.',
#   'category': ['과학-천기(天氣)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101010_001',
#   'title': '조석전을 지내고 상식을 올리다',
#   'content': '상이 조석전을 지내고 상식을 올렸다.',
#   'category': ['왕실(王室)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101010_002',
#   'title': '대사헌 이해 등이 임억령·홍언필 등의 체직을 청하다',
#   'content': ' 대사헌 이해 등이 아뢰기를,"임억령 등은 이미 물론을 입었으므로 직에 있을 수 없는 형세이고 홍언필은 이미 중한 논박을 입었으니, 모두 빨리 체직시키소서."하니, 답하기를,"간원은 체직해도 되지만 좌상은 기구 대신(耆舊大臣)이니 요동할 수가 없기 때문에 윤허하지 않는다."하였다.',
#   'category': ['정론-간쟁(諫諍)', '인사(人事)', '사법-탄핵(彈劾)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101010_003',
#   'title': '햇무리가 지다',
#   'content': '햇무리가 지고 양이가 있었다.',
#   'category': ['과학-천기(天氣)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101010_004',
#   'title': '밤에 검은 기운이 뻗치다',
#   'content': '밤에 구름 같은 흑기(黑氣)가 동서로 가로질러 뻗쳐 있었다.',
#   'category': ['과학-천기(天氣)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101011_001',
#   'title': '조석전을 지내고 상식을 올리다',
#   'content': '상이 조석전을 지내고 상식을 올렸다.',
#   'category': ['왕실(王室)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101011_002',
#   'title': '좌의정 홍언필의 사직서를 정원에 내리다',
#   'content': ' 좌의정 홍언필의 사장(辭狀) 【중한 증세가 더 생겨 고질이 되었으므로 결코 살 수 없으니 빨리 체직시켜 달라는 내용이었다.】 을 정원에 내리며 일렀다."병의 증세는 한때 심해졌다 하나 날씨가 점점 따뜻해지고 있으니 어찌 오래도록 낫지 않겠는가. 마음을 편히 하고 조리하라는 뜻으로 이르라."',
#   'category': ['인사(人事)', '보건(保健)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101011_003',
#   'title': '대사헌 이해 등과 정언 김난상이 홍언필의 체직을 청하다',
#   'content': ' 대사헌 이해 등과 정언 김난상(金鸞祥)이 합사(合司)하여 아뢰기를,"홍언필은 정승 자리에 맞지 않아서 이미 중한 논박을 받았으므로 직에 있을 수 없는 형세입니다. 그러므로 스스로 이런 줄 알고 병을 핑계대어 사피하는 것인데 위에서는 선조의 구신을 경솔히 바꿀 수 없다 하여 망설이면서 오래 지체하시었으니 이제 체직을 명하시더라도 어쩔 수 없는 형세 때문이지 어찌 구신을 박대해서 바꾸는 것이라고 하겠습니까. 의시(議諡)는 큰일인데 홍언필이 정승 자리에 있으나 논박을 받았으므로 우상이 홀로 신하들과 의논하였으니, 사체가 이미 마땅하지 못하였습니다. 또 산릉(山陵)의 일이 임박했고 중국 사신도 나올 것이므로 큰일이 거듭되는데 정승 자리를 오래 비워 두는 것은 더욱 마땅하지 않습니다. 빨리 체직시키소서."하니, 답하기를,"좌상은 논박을 받았기 때문에 병을 핑계하여 사퇴하는 것이 아니다. 의원을 보내어 진찰하였더니 그의 증세가 매우 중하다고 한다. 내 생각은 부왕의 신하이기 때문에 바꾸려 하지 않는 것이지 어찌 사람들의 후하니 박하니 하는 말 때문에 그러는 것이겠는가. 의시는 진실로 큰일이므로 내가 좌상을 함께 참여시키려 하였는데 그날 좌상이 병으로 참여하지 못하였다. 그러나 조정이 다 모였고 일도 급하므로 형세가 어쩔 수 없어서 우상만 참여하였는데, 어찌 사체에 맞지 않았다고까지 할 수 있겠는가. 산릉과 중국 사신 등의 일을 나도 생각하였는데 그때에는 삼공(三公)이 자리를 갖추어서 일을 처리해야 할 것이다. 그래서 윤허하지 않는다."하였다.',
#   'category': ['왕실(王室)', '정론-간쟁(諫諍)', '인사(人事)', '사법-탄핵(彈劾)', '외교-명(明)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101011_004',
#   'title': '원상 윤인경에게 정승을 선발할 것을 재촉하다',
#   'content': '작은 종이에 쓴 글을 정원에 내리면서 이르기를,"이것을 원상(院相)에게 주라."하였는데, 그 글에 이르기를,"보상(輔相)의 벼슬은 온갖 책임이 집중되는 곳이니 정승이 적격자이면 편안하게 잘 다스려지고 그렇지 못하면 난망(亂亡)이 뒤따르게 된다. 그러므로 예전의 현명한 임금은 모두 상신(相臣)의 선발을 중히 여겨 반드시 널리 학식이 높고 덕이 큰 선비를 가려서 맡겼으므로 판축(版築) 가운데에서 뽑은 자045)  까지 있었다. 이제 수상(首相) 자리가 오래 비어 있고 장기(葬期)가 이미 임박 【 윤은보(尹殷輔)의 장기이다.】 하였으므로 두 정승을 차례로 승진 발령해야겠으니 대신할 사람을 선발해야 할 것이다. 생각하건대, 우리 선조(先朝)에서는 인재의 배양이 성대하다 할 수 있어 뽑아서 제수함에 있어서는 반드시 적격자가 있을 것이니 덕망이 있는 자를 삼가 선발하여 그 자리에 두어야 한다. 내가 부덕한 몸으로 참혹한 큰 변을 당하여 망연히 잘 살필 수가 없어서 무릇 나라를 다스리는 중대한 일을 모두 대신에게 의지하고 있다. 어진 보상을 얻게 된다면 이는 나라의 복이겠다."하였다. 원상 윤인경(尹仁鏡)이 회계하기를,"정승의 직은 지극히 중난한 것이어서 국가의 안위가 여기에 달려 있는데, 신은 재덕(才德)이 없이 정승 자리에 무릅쓰고 있으므로 인재(人才)의 현부(賢否)를 모르니 어떻게 복상(卜相)할 수 있겠습니까? 옛부터 복상은 혼자한 때가 없는데 홍언필은 인피(引避)하여 집에 있으니, 신이 혼자 하는 것은 더욱 미안하여 감히 아룁니다."하니, 답하기를,"같이 의논할 사람이 없으니 어쩔 수 없이 혼자 해야 할 형세이다. 빨리 선발해야 한다."하였다.',
#   'category': ['정론-정론(政論)', '행정-중앙행정(中央行政)', '인사(人事)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101011_005',
#   'title': '대간이 합사하여 홍언필의 일을 아뢰다',
#   'content': '대간이 합사(合司)하여 홍언필의 일을 세 번 아뢰었으나 윤허하지 않았다.',
#   'category': ['정론-간쟁(諫諍)', '인사(人事)', '사법-탄핵(彈劾)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101011_006',
#   'title': '윤인경이 재상의 후보를 아뢰다',
#   'content': ' 윤인경이 복상한 사람의 이름을 봉함(封緘)하여 아뢰었는데, 유관(柳灌)과 이기(李芑)였다.',
#   'category': ['행정-중앙행정(中央行政)', '인사(人事)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101011_007',
#   'title': '구수담·이윤경·곽순 등에게 관직을 제수하다',
#   'content': ' 구수담(具壽聃)을 승정원 동부승지로, 이윤경(李潤慶)을 사간원 대사간으로, 곽순(郭珣)을 사간으로, 민전(閔荃)을 장령으로, 심봉원(沈逢源)을 헌납으로, 노수신(盧守愼)을 정언으로 삼았다.',
#   'category': ['인사-임면(任免)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101011_008',
#   'title': '햇무리가 지다',
#   'content': '햇무리가 지고 관이 있었다.',
#   'category': ['과학-천기(天氣)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101012_001',
#   'title': '조석전을 지내고 상식을 올리다',
#   'content': '상이 조석전을 지내고 상식을 올렸다.',
#   'category': ['왕실(王室)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101012_002',
#   'title': '대간이 홍언필의 일을 아뢰다',
#   'content': '대간이 합사하여 홍언필의 일을 두 번 아뢰었으나 윤허하지 않았다.',
#   'category': ['정론-간쟁(諫諍)', '인사(人事)', '사법-탄핵(彈劾)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101012_003',
#   'title': '간원이 민전의 체직을 청하다',
#   'content': '간원이 아뢰기를,"장령 민전은 본디 지식이 없고 또 비루한 일이 많아서 대관에 맞지 않으니 체직 시키소서."하니, 아뢴 대로 하라고 답하였다.  사신은 논한다. 민전이 서장관(書狀官)으로 윤원형(尹元衡)을 따라 북경(北京)에 갔을 때에 통사(通事) 박정원(朴貞元)이 중전(中殿)의 무역(貿易)이라 칭하면서 외람되이 마음대로 하는데도 이를 전혀 단속하지 않고 또 스스로도 삼가지 않았으므로 더럽게 여기는 사람들이 많았다.',
#   'category': ['정론-간쟁(諫諍)', '인사(人事)', '사법-탄핵(彈劾)', '외교-명(明)', '역사-사학(史學)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101012_004',
#   'title': '부제학 송세형 등의 재상 선발에 관한 차자',
#   'content': ' 홍문관 부제학 송세형 등이 차자를 올리기를,"삼가 복상(卜相)하라는 본부를 보건대 위에서 상신(相臣)의 선발에 치란이 달려 있다는 것을 깊이 통촉하시어 반드시 학식이 높고 덕이 큰 선비를 널리 가려서 발탁하여 제수하려 하셨으니 신중히 가리는 뜻이 지극하셨습니다. 신들은 감격함을 견딜 수가 없습니다. 대개 임금이 하늘을 대신하여 만물을 다스림에 있어 더불어 함께하는 자는 대신이고 대신의 직책은 만백성이 제자리를 얻게 하는 것이므로 그 직임이 중대한 것입니다. 더구나 대를 이은 처음으로 정시(正始)하는 때이니, 더욱 어렵게 여기고 삼가야 합니다. 군자 하나가 나아오면 뭇 군자가 몰려 나아오고 소인 하나가 나아오면 뭇 소인이 나아오게 되는 것이니 소장(消長)의 기틀을 두렵게 여기지 않을 수 있겠습니까.옛 임금이 어렵게 여긴 까닭은 오직 적임자를 찾는 것이었으므로 판축에서 뽑은 자도 있었습니다. 선조(先朝) 40년 동안 배양한 끝에 어찌 성지(聖旨)에 이르신 바와 같이 덕망이 있는 자가 없겠습니까. 여망에 맞는 적격자가 있다면 또한 상례(常例)에 구애될 것이 없는 것입니다. 바라건대 전하께서는 더욱 더 어렵게 여기고 삼가서 두루 찾고 널리 가려서 그 직임을 중하게 여기소서."하니, 답하기를,"내 뜻은 본디 널리 가리려 한 것인데 어제 복상한 뜻을 보니 혹 생각하는 바가 있는 듯하다. 이제 차자의 사연을 보면 논한 것이 지극히 마땅한데 여망에 맞는 자가 있더라도 내가 어떻게 알 수 있겠는가. 관중(館中)에서는 반드시 가리키는 데가 있을 것이니 말하여 내 희망에 부응하라. 내가 짐작하여 조처하겠다."하였다.',
#   'category': ['정론(政論)', '인사(人事)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101013_001',
#   'title': '조석전을 지내고 상식을 올리다',
#   'content': '상이 조석전을 지내고 상식을 올렸다.',
#   'category': ['왕실(王室)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101013_002',
#   'title': '부제학 송세형 등이 재상 선발에 관해 대신에게 물을 것을 청하다',
#   'content': ' 홍문관 부제학 송세형 등이 아뢰기를,"신들의 차자에 답하신 분부를 보니 황공함을 견디지 못하겠습니다. 신들의 뜻은, 정승 자리는 지극히 중하므로 반드시 두루 찾고 널리 가려서 적임자를 얻게 되기를 바랐을 뿐입니다. 복상은 대신의 책임으로 신들이 간여할 바가 아닌데 이제 신들에게 지적해서 말하게 하시니 이는 사체에 방해가 될 듯합니다. 일국의 공론을 대신이 모르지는 않을 것이니 다시 하문하여 어렵게 여기고 삼가는 도리를 다하셔야 하겠습니다."하니, 답하기를,"내 뜻은 지적해 말하게 하려는 것이었는데 아뢴 바가 이러하니 알았다."하였다.',
#   'category': ['정론(政論)', '인사(人事)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101013_003',
#   'title': '대간이 합사하여 홍언필의 일을 아뢰다',
#   'content': '대간이 합사하여 홍언필의 일을 아뢰었으나 윤허하지 않았다.',
#   'category': ['정론-간쟁(諫諍)', '인사(人事)', '사법(司法)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101013_004',
#   'title': '대간이 이기의 관직 제수를 개정할 것을 청하다',
#   'content': '대간이 아뢰기를,"이기(李芑)는 본디 물망이 없어서 찬성(贊成)에 제수되었을 때부터 물론이 있었는데 중한 자리에 오래 있었으니 외람됨이 이미 심했습니다. 정승 자리로 말하면 결코 의의(擬議)할 수가 없는데 이제 의정(議政)을 삼았으므로 물정이 해괴하게 여기니 빨리 개정하소서." 【이날 정사(政事)에서 이기가 우의정에 제배되었으므로 대간이 즉시 논계하였다.】   하니, 답하기를,"복상할 때에 어찌 범연하게 생각해서 하였겠는가. 고칠 수 없다."하였다.',
#   'category': ['정론-간쟁(諫諍)', '인사(人事)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101013_005',
#   'title': '홍언필·윤인경·이기 등에게 관직을 제수하다',
#   'content': ' 홍언필을 의정부 영의정으로, 윤인경을 좌의정으로, 이기를 우의정으로, 성세창을 좌찬성으로, 이언적을 우찬성으로, 허자를 지중추부사로, 박우(朴祐)를 한성부 좌윤으로, 송희규(宋希奎)를 사헌부 장령으로 삼았다.',
#   'category': ['인사-임면(任免)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101014_001',
#   'title': '조석전을 지내고 상식을 올리다',
#   'content': '상이 조석전을 지내고 상식을 올렸다.',
#   'category': ['왕실(王室)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101014_002',
#   'title': '좌의정 윤인경이 이기에 대한 공론을 아뢰다',
#   'content': ' 좌의정 윤인경이 아뢰기를,"국가의 치란과 안위는 재상에게 달려 있기 때문에 위에서는 덕망이 있는 사람을 얻어서 정승으로 삼으려 하시고 아래에서도 덕망이 있는 사람이 정승이 되는 것을 보려 합니다. 상하가 다 이런 마음이 있는데 이제 위에서 수성(守成)하는 군주가 되셨으므로 중외(中外)에서는 화평한 정치가 이루어지기를 우러러 바라니, 조정에 충후(忠厚)한 기상이 있어 오래도록 유지된다면 치화(治化)가 절로 아름다와질 것입니다. 지난번 복상하라는 명이 계셨는데 신이 혼자서 하기가 매우 어렵고 또 용렬하여 사람을 알아볼 수 없으므로 어렵게 여기고 삼가야 한다는 뜻으로 계달하였습니다만, 위에서 굳이 명하시기에 신이 사양하지 못하고 천거하였던 것입니다. 지금에 어찌 복상에 합당한 사람이 없겠습니다마는 옛날과 지금은 때가 다르고 조종(祖宗) 때에도 이런 일이 없었습니다. 하루아침에 발탁하여, 대를 이어온 기구 대신(耆舊大臣)의 위에 둔다면 그사람도 어려워할 것입니다. 이기(李芑)는 기구 대신이기 때문에 신이 아울러 써서 아뢴 것인데 공론(公論)이 이렇게까지 될 줄은 신이 미처 생각하지 못하였습니다. 신이 이제 복상하였는데 물론이 이러하여 조정이 소요스러운 듯하니 매우 황공스럽습니다."하니, 답하기를,"반복하여 헤아려보았으나 경이 복상한 것이 대체에 무슨 방해가 되겠는가. 우상에 대한 물론이 있을 것을 미처 생각하지 못하였을 뿐인데 무슨 황공할 것이 있는가. 지금은 나랏일이 오로지 정승에게 의지할 뿐이다. 영상의 일도 편치 못한데 더구나 우상이 새로 제배되자 물론이 이러하니 더욱 어찌할 바를 모르겠다."하였다.',
#   'category': ['정론(政論)', '인사(人事)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101014_003',
#   'title': '대간이 합사하여 홍언필과 이기의 체직을 청하다',
#   'content': '대간이 합사하여 아뢰기를,"홍언필이 직에 있을 수 없다는 뜻은 이미 다 아뢰었으니 빨리 체직시키소서. 우의정 이기는 인물이 비열하고 본디 지식이 없으며 처신과 행사에 꺼리는 바가 없습니다. 한때 요행히 이공(貳公)046)  의 자리에 외람되게 올랐으나 물론에 용납되지 못한 지 오래입니다. 이제 복상한 때에 또 위차(位次) 때문에 참여되어 드디어 정승 자리에 올랐으나 물정의 기대 밖에서 나온 것이니 빨리 개정하소서."하니, 답하기를,"영상에 대한 일은 이미 다 일렀다. 우상은 선조 때부터의 기구인이고 벼슬도 차례가 닿았으므로 제배한 것이다. 대신을 이미 제배하였으니 가벼이 움직일 수 없다. 가벼이 움직이면 대신의 자리가 도리어 중하지 않게 되고 사람들이 이런 사실을 듣게 되면 소요스럽게 될 것이니, 개정할 것 없다."하였다. 다시 아뢰었으나 윤허하지 않았다.',
#   'category': ['정론-간쟁(諫諍)', '인사(人事)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101014_004',
#   'title': '정원이 임금이 곡하는 위치에 관해 서계하다',
#   'content': '정원이 서계(書啓)하기를,"예문(禮文)에 ‘전하의 곡위(哭位)는 빈전(殯殿) 지게문 밖의 동쪽에 둔다.’ 하였는데, 동계(東階) 아래에 설치하여 대군(大君)·제군(諸君)과 나란하게 하고 계상(階上)은 포장을 둘러 안팎을 막았으므로 신들이 옳지 않다는 뜻을 여러번 아뢰니, 위에서는 내차(內次)에 가깝다 하시어 드디어 서계(西階)위로 옮겨 설치하였습니다. 무릇 삭망전(朔望奠)과 속절 별전(俗節別奠)에는 통례(通禮)·승지(承旨)·사관(史官)도 모두 입시(入侍)하도록 허가하는데, 이는 조정이 거행하는 것이기 때문입니다. 조정의 거동이 있다면 곡위를 설치하는 것도 의당 예문에 따라야 할 것인데, 신들이 지난번 삭전(朔奠)에서 보건대 동계 위의 포장을 걷어올리고 사람들이 또 통행하였으며 곡위는 오히려 서쪽에 설치하였으니, 신들은 매우 온편하지 못하다고 생각합니다.대비(大妃)의 진향(進香)에 대한 의주(儀註)에 ‘대비의 자리를 지게문 밖의 동쪽에 설치하고 전하의 자리는 서계위에 설치한다.’ 하였는데, 이것이 권의(權宜)를 따른 것이라고는 하나 이미 바른 예의가 아닙니다. 신들이 삼가 살피건대, 《예경(禮經)》 상대기편(喪大記篇)에 정시(正尸)047)  하고 나면 아들은 동쪽에 앉고 부인(夫人)은 서쪽에 앉는다.’고 하였는데 그 주(註)에 ‘이것은 국군(國君)의 상(喪)을 말한 것이다.’ 하였고, 금화 응씨(金華應氏)는 ‘남자는 동쪽에 앉고 여자는 서쪽에 앉는 것은 음양(陰陽)의 큰 구분이다. 갑자기 상을 당하여 슬픔이 절박한데다 사람이 뒤섞이고 일이 번다하니 먼저 남녀의 구별을 삼가서 각각 유대로 따르게 하면 분란(紛亂)한 것이 질서가 있게 될 것이다. 남자 주인이 동쪽 웃자리에 있고 안의 가장(家長)은 어머니라도 그 서쪽에 있게 되면, 한 나라와 한 집안에 주인이 있게 되어 통섭(統攝)이 되게 될 것이다.’ 하였습니다. 또 상대기편에 ‘당상(堂上)에서 주검에 대하여 곡할 때에 주인은 동쪽에 있는다.’ 하였는데, 그 주에 ‘부인의 곡위(哭位)는 본디 서쪽에서 동쪽을 향한다.’ 하였고, 엄릉 방씨(嚴陵方氏)는 ‘예의의 분별은 남녀의 관계에 대해 더욱 중한 것이니 상을 갑자기 당한 가운데에서도 누구나 다 각각 제 자리를 바르게 하는 것이다. 그러므로 남자는 서쪽을 향하여 동쪽에 자리하고 부인은 동쪽을 향하여 서쪽에 자리하는 것이니 이는 음양을 분별하는 뜻인 것이다.’ 하였습니다. 이로써 살펴보면 동계 위의 곡위는 결코 옮길 수 없으니 예문에 따라 지게문 밖의 동쪽에 설치하소서."하니, 전교하기를,"아뢴 뜻은 내가 이미 잘 알고 있다. 예문(禮文)은 그러하더라도 동쪽은 수라간(水剌間)에 가까와 예찬(禮饌)을 올리느라 드나드는 곳이므로 권의에 따라 서계에 설치 한 것이다. 이제 고쳐 설치하면 드나들기가 편리하지 못한 것이니 고치지 않아도 무방하겠다."하였다.',
#   'category': ['왕실(王室)', '정론-정론(政論)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101015_001',
#   'title': '삭전을 지내고 상식을 올리다',
#   'content': '상이 삭전(朔奠)을 지내고 상식(上食)을 올렸다.',
#   'category': ['왕실(王室)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101015_002',
#   'title': '대간이 합사하여 홍언필과 이기의 체직을 청하다',
#   'content': '대간이 합사하여 아뢰기를,"대신이 중한 논박을 받으면 완고하고 어리석어 부끄러움이 없는 사람이라도 감히 다시 그 벼슬에 나아가지 못하는 것이니, 신들이 굳이 논집하지 않더라도 홍언필이 어떻게 감히 그 자리에 무릅쓰고 있겠습니까. 이기의 일에 대해 위에서 ‘대신이 이미 제배되었으면 경솔히 움직일 수 없다.’고 하였으나, 적격자가 아니라면 국가의 위란이 뒤따르는 것이니 어찌 제배되었다 하여 개정하지 않을 수 있겠습니까. 또 ‘가볍게 움직이면 대신의 자리가 도리어 중하지 않게 될 것이다.’고 분부하셨으나, 적격자가 아닌데 그 자리에 무릅쓰고 있게 된다면 그것이 곧 그 자리를 더욱 가볍게 하는 바가 되는 것입니다. 적격자를 얻지 못한다면 열 번을 바꾸더라도 소요스러움이 되지 않는 것입니다. 한 나라의 흥망을 생각하지 않을 수 있겠습니까. 더구나 지금은 사복(嗣服)하신 처음으로 더욱 삼가서 선발하지 않을 수 없으니 빨리 개정하도록 명하소서."하니, 답하기를,"정승의 자리에 대해 내 생각으로는 가볍게 고칠 수 없다고 여기고 있다. 그러나 지금 나라의 큰 일이 이미 임박하였으므로 애써 공론을 따른다. 다만 이기의 가자(加資)048)  는 고칠 수 없다."하였다.',
#   'category': ['정론-간쟁(諫諍)', '인사(人事)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101015_003',
#   'title': '대간이 이기의 자급을 올려 준 것을 개정하라고 청하다',
#   'content': '대간이 아뢰기를,"이기는 이미 정승 자리에 맞지 않아서 논박받아 체직되었으니 중한 가자를 그대로 줄 수는 없습니다. 빨리 개정하소서."하니, 답하기를,"이미 정승에서 체직하였는데 또 가자까지 고치는 것은 너무 심하지 않은가. 고칠 것 없다."하였다.',
#   'category': ['정론-간쟁(諫諍)', '인사(人事)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101015_004',
#   'title': '정원이 거상 중에 권제를 따를 것을 청하다',
#   'content': '정원이 《예경(禮經)》에서 베껴 써서 【＊】  아뢰기를,"근래 바깥 사람들이 전하는 말에 의하면 ‘위에서 전혀 찬선(饌膳)을 드시지 않아 애통으로 인한 수척이 너무 지나치다.’고 하는데, 신들이 지난번 삭망전(朔望奠) 때 보건대, 위에서 잘 걷지도 못하고 옥색(玉色)도 전만 못하셨습니다. 신들이 목도한 바로는 바깥의 말이 헛되지 않은 듯하여 슬프고 민망하기 그지없습니다. 대저 어버이의 상을 치를 때에 그 애통한 정은 위아래가 다 같은 것입니다만 제왕의 효도는 서민과는 다릅니다. 종묘(宗廟)와 사직(社稷)의 주인으로서 지나치게 슬퍼하여 목숨을 손상하여서는 안 되는 것입니다. 그래서 선왕의 제례(制禮)와 조종의 유교(遺敎)는 【 세종(世宗)의 유교를 가리킨다. 처음에 보인다.】  다 종사(宗社)의 대계를 위하여 후세를 위한 알맞은 제도를 만든 것이니 어찌 먼 앞일을 생각한 것이 아니라고 할 수 있겠습니까. 이제 큰일이 있는 때를 당하여 옥체가 지나치게 손상되시니 조정 상하가 다 망극해 합니다. 바라건대 선왕의 알맞은 제도를 힘써 따르시어 찬선을 들고 조리하소서. 이것은 《예경》의 말로 위에서 평소 강론하시던 것입니다마는, 경황 없는 중에 어찌 다 기억하실 수 있겠습니까. 그래서 베껴 써서 들이니 위에서는 이것을 살펴 슬픈 정을 조금 억제하소서."하니, 전교하기를,"아뢴 뜻은 내가 이미 잘 알고 있다."하였다.  【＊ 《예경》에서 베껴 쓴 것은 이러하다."곡례(曲禮)에 ‘거상(居喪)하는 예(禮)는 애통하여 수척하더라도 철골이 되게까지 하여서는 안 되고 시력과 청력이 약해지게까지 하여서는 안된다. 거상하는 예는 머리나 몸에 부스럼이나 가려움병이 나면 목욕하고 병이 생기면 술도 마시고 고기도 먹되 병이 나으면 처음으로 돌아간다. 병 때문에 상례를 견디어내지 못하는 것은 곧 불자(不慈)와 불효(不孝)에 비견된다.’ 하였습니다. 단궁(檀弓)에 ‘증자(曾子)가 자사(子思)에 「 급(伋)아, 내가 어버이의 상을 지낼 때에는 이레 동안 수장(水漿)도 마시지 않았다.」 하니, 자사가 「선왕(先王)이 예를 제정할 때에 지나친 것은 억제하여 알맞게 하고 모자라는 것은 돋우어 미치게 하였으므로, 군자가 어버이의 상을 지낼 때에는 사흘 동안 수장을 마시지 않는 것인데 지팡이를 짚고서야 일어날 수 있습니다.」 하였다.’ 하고, 또 ‘애통하여 수척하되 몸을 위태롭게까지 하지는 않으니, 그렇게까지 하면 자손이 끊어지게 되기 때문이다.’ 하고, 또 ‘악정 자춘(樂正子春)이 어머니가 죽자 닷새 동안 먹지 않고는 「나는 뉘우친다. 우리 어머니에게도 참뜻대로 다하지 않았는데 내가 어디엔들 참뜻대로 할 수 있겠는가.」 하였다.’ 하였습니다. 잡기(雜記)에 ‘공자(孔子)가 「애통하여 수척해서 병이 되게 하는 것은 군자가 하지 않는 일이다. 수척하여 죽는 것을 군자는 아들이 없는 것과 마찬가지로 여긴다.」 하였다.’ 하였고, 상복사제(喪服四制)에 ‘사흘 만에 먹고 석 달 만에 목욕하고 1년 만에 연복(練服)하여 수척하되 목숨을 끊어지게까지 하지 않는 것은 죽음 때문에 삶을 손상하지 않게 하기 위한 것이다.’ 하였습니다."】\r\n\t\t\t\t\t\t\r\n\r\n\t\t\t\t\t\t\r\n\t\t\t\t\t\t',
#   'category': ['왕실(王室)', '정론-정론(政論)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101015_005',
#   'title': '정원이 중종의 어용을 그릴 것을 아뢰다',
#   'content': '정원이 아뢰기를,"조종(祖宗)들은 모두 어용(御容)을 그렸는데 대행 대왕의 어용을 평상시에 그려 두지 않았으니 세월이 오래 가기 전에 본떠 그리는 것이 마땅하겠습니다. 성종(成宗)께서는 갑인년049)   12월에 승하하셨는데 을묘년050)   2월에 뒤미치어 그렸으니 이제도 뒤미치어 그리는 것이 어떠하겠습니까?"하니 전례에 따라서 하라고 전교하였다.',
#   'category': ['왕실(王室)', '예술-미술(美術)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101016_001',
#   'title': '조석전을 지내고 상식을 올리다',
#   'content': '상이 조석전을 지내고 상식을 올렸다.',
#   'category': ['왕실(王室)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101016_002',
#   'title': '정원에 복상과 정사를 전교하다',
#   'content': '정원에 전교하기를,"삼공에 빈 자리가 있으니 사관(史官)을 좌상에게 보내어 복상하도록 하라."하였다. 주서(注書) 왕희걸(王希傑)이 좌의정 윤인경에게 가서 물으니, 대답하기를,"신이 예궐하여 아뢰겠습니다."하고, 이윽고 정원에 와서 아뢰기를,"어제 전교를 보니, 홍언필·이기는 물론이 현저하게 발론되었으므로 위에서 마지못하여 따르셨다고 하였습니다. 이기가 논박받은 것은 신이 잘못 천거하였기 때문 입니다. 또 즉위한 처음에 상신(相臣)을 한꺼번에 체직시키는 것도 미안한 일입니다. 신은 배우지 못하여 학술이 없는데도 요행히 급제하였으므로 늘 백집사(百執事)로서 업무에 충실하기를 기망(期望)하였으나 티끌만한 도움도 없었는데 여러번 분수에 맞지 않는 직을 맡았습니다. 더구나 모두가 우러르는 정승 자리는 결코 신이 무릅쓰고 있을 곳이 아닌데 정승 자리에 있은 지 이제 6년이나 되었고 나이도 70이므로 기력이 쇠약하고 정신이 혼몽하여 나랏일을 감당할 수 없는 처지입니다. 의리상 곧 치사(致仕)해야 할 것인데도 지금 나라에 큰 일이 있으므로 애써 일하여 왔는데, 이제 두 정승이 함께 체직되었다 하여 좌목(座目)051)  을 살펴보니 신보다 위가 없습니다. 수상(首相)은 훌륭한 덕이 있는 노성(老成)한 사람을 써야 하는 것인데 신은 학술이나 지식이 없습니다. 그런데도 수상의 자리에 있게 되면 나랏일이 날로 글러져서 물론이 일어날 것이고 물론이 일어나면 신은 물러나게 될 것이니, 위에서 대신을 중히 여기시는 뜻에 미안하지 아니하겠습니까? 또 즉위한 처음의 정사(政事)에서 두 정승을 함께 체직하는 것은 매우 미안하며 두 정승은 다른 벼슬과 같지 않은 것인데 한꺼번에 차출하는 것은 대신을 중히 여기는 뜻에 어그러지는 듯합니다. 신의 어리석은 생각으로는 전일에 써서 아뢴 한 사람 【 유관(柳灌).】 을 정승으로 삼는 것이 마땅할 듯합니다."하니, 답하기를,"아뢴 뜻은 알았다. 내 생각에도 이런 때에 두 정승을 함께 체직하는 것이 미안한줄 모르는 것은 아니지마는, 이제 나라에 큰일이 있고 양사(兩司)는 여러날 논계하는데 영상이 또 병으로 간절히 사퇴하므로 애써 공론을 따르는 것일 따름이다. 이제 아뢴 뜻을 보니 더욱 미안하나 좌상의 겸양(謙讓)하는 뜻에 따라 한 정승만을 차출할 수는 없다. 다만 일시에 두 정승을 함께 차출하는 것은 과연 대신을 존중하는 뜻이 아니므로 경이 아뢴 바를 따라 우상만을 차출하라. 또 유관은 선조(先朝)에서 서방(西方)의 일을 중히 여겼으므로 특별히 위임하였었는데 바야흐로 중국 사신이 나오게 되어 분주한 일이 많을 것이기 때문에, 전에 서울에 있는 사람을 정승에 제배하였을 뿐이다."하고, 이어 정원에 전교하기를,"이제 이미 복상하였으니 내일 정사를 하도록 하라."하였다.',
#   'category': ['정론-정론(政論)', '인사(人事)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101016_003',
#   'title': '간원이 곡하는 위치를 바로잡을 것을 청하다',
#   'content': '대간이 이기의 일을 아뢰었으나 윤허하지 않았다. 간원이 아뢰기를,"예문(禮文)에 빈전(殯殿) 앞의 내외(內外)의 곡위(哭位)는 동서로 분별하여 각각 정한 곳이 있으므로 옮길 수 없습니다. 더구나 동계는 임금이 즉위하는 자리이어서 결코 문란하게 할 수 없습니다. 이번에 전하의 곡위를 서계 위에 설치하면 전도됨이 너무 심하니 권제(權制)에 따른다 핑계하여 예가 아닌 것을 구차하게 따를 수 없습니다. 예문에 따라 빨리 위차(位次)를 바로잡으소서."하니, 아뢴 대로 하라고 답하였다.',
#   'category': ['정론-간쟁(諫諍)', '인사(人事)', '왕실(王室)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101017_001',
#   'title': '조석전을 지내고 상식을 올리다',
#   'content': '상이 조석전을 지내고 상식을 올렸다.',
#   'category': ['왕실(王室)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101017_002',
#   'title': '좌의정 윤인경과 좌찬성 성세창이 찬선을 들 것을 권하다',
#   'content': ' 좌의정 윤인경(尹仁鏡)과 좌찬성 성세창(成世昌)이 아뢰기를,"위에서 애통망극해 하는 정에 어찌 끝이 있겠습니까마는, 대행 대왕(大行大王)께서 병환이 위독하실 때에도 곁에서 오래 모시느라 찬선(饌膳)을 드신 적이 없는데 대고(大故)를 당하여서는 애통해 하심이 예도에 지나쳐 이제까지 찬선을 드시지 않는다 하니, 매우 놀랍습니다. 제왕의 효도는 여느 사람과 다르고 또 예문(禮文)에도 ‘애통해 하여 수척한 것이 중도에 지나친 것은 군자가 하지 않는다.’ 하였는데, 이는 어진 사람은 감히 중도에 지나치지 않게 하고 불초한 자는 중도에 미치게 하여 예문에 맞게 되기를 바란 것입니다. 이렇게 하는 것이 큰 효도이니 종사(宗社)의 대계를 위하여 애써 찬선을 드소서. 신들의 뜻만이 이런 것이 아니라 온 조정의 뜻이 다 그러합니다."하니, 답하기를,"내가 별로 예도에 지나치게 한 일이 없는데 이제 아뢴 사연을 들으니 매우 부끄러움을 느낀다. 마땅히 생각하여 부응할 수 있게 하겠다."하였다.',
#   'category': ['왕실(王室)', '정론(政論)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101017_003',
#   'title': '대간이 이기의 일을 아뢰다',
#   'content': '대간이 이기의 일을 아뢰었으나 윤허하지 않았다.',
#   'category': ['정론-간쟁(諫諍)', '인사(人事)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101018_001',
#   'title': '조석전을 지내고 상식을 올리다',
#   'content': '상이 조석전을 지내고 상식을 올렸다.',
#   'category': ['왕실(王室)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101018_002',
#   'title': '대간이 이기의 자급 개정을 청하다',
#   'content': '대간이 아뢰기를,"이기에게 중한 가자(加資)를 그대로 줄 수 없으니 개정하도록 명하소서."하니, 답하기를,"여러날 논집하므로 윤허한다."하였다.  사신은 논한다. 이기는 윤원로(尹元老)·윤원형(尹元衡)과 교제하고 몰래 궁위(宮闈)와 교통하여 대행대왕께 중하게 여김을 받아 이공(貳公)의 반열에까지 이르렀다. 영상 윤은보(尹殷輔)가 졸(卒)한 뒤부터 사림(士林)이 모두 이기가 정승이 되리라고 의심하여 이미 탄핵할 뜻을 굳히고 있던 차여서 이 명이 있었으나 이기가 끝내 보전할 수 없었다. 이언적(李彦迪)이 일찍이 이기의 집에 갔을 때 말이 양궁(兩宮)의 일에 언급되었는데, 이언적이 ‘중전(中殿)이 동궁(東宮)을 【전하가 동궁으로 있을 때이다.】  매우 박대하니 놀라운 생각을 견딜 수 없다.’ 하였다. 이언적의 이 말은 들은 사람이 없었는데 이기가 곧 윤원로에게 누설하였으므로 원로가 이언적을 원망하여 드디어 소원하게 대하였다. 원로는 이기를 덕스럽게 여겨 ‘이기는 이학(理學)에 정통한데 중국에서 찾아보아도 필적할 만한 사람이 없다.’고 칭찬하였다.',
#   'category': ['왕실(王室)', '정론-간쟁(諫諍)', '인사(人事)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101018_003',
#   'title': '정원이 대행 대왕의 어용 그리는 일에 관해 아뢰다',
#   'content': '정원이 아뢰기를,"전에는 대행 대왕의 어용을 그리는 일을 종부시(宗簿寺)가 으레 맡았으나, 이번에는 상례(常例)와 달라서 추상(追想)하여 그리므로 진용(眞容)에 가깝기가 매우 어려우니 범연히 밖에다 맡길 수 없습니다. 바라건대, 명정전(明政殿) 양쪽 행랑에 화국(畫局)을 설치하고 평소에 가까이 모시던 종친인 이성군(利城君)  【이름은 관(慣).】 과 평소에 입시하던 내관 너덧 사람에게 그 일을 감장(監掌)시키게 하소서. 좌찬성 성세창이 그림 격식을 아니 감교(監校) 시키소서. 두성령(杜城令) 암(巖)이 그림을 잘 그리고 사노(私奴) 상좌(上佐)도 잘 그리니, 아울러 참여하여 그리게 하는 것이 어떠하겠습니까?"하니, 그리하라고 전교하였다.',
#   'category': ['왕실(王室)', '예술-미술(美術)', '신분-천인(賤人)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101019_001',
#   'title': '조석전을 지내고 상식을 올리다',
#   'content': '조석전을 지내고 상식을 올렸다.',
#   'category': ['왕실(王室)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101019_002',
#   'title': '함경도 관찰사 이청이 재변을 장계하다',
#   'content': ' 함경도 관찰사 이청(李淸)이 장계(狀啓)052)  하기를," 종성 부사(鍾城府使) 유지선(柳智先)의 첩정(牒呈)053)  에 ‘갑진년054)   12월 14일 신시(申時)에 해의 북쪽에 세 무지개가 나란히 섰다. 길이는 하늘 끝까지 닿았고 세 무지개가 중간이 서로 맺었고 양끝은 다 태양이 희미하게 비쳤으며 형상은 둥근 쟁반과 같았는데 한참 만에 사라졌다. 같은 달 15일 초경(初更)에 달무리가 졌는데 달무리 남북에 큰 쟁반 같은 형상의 백기(白氣)가 일고 또 피륙을 누인 듯한 백기가 서쪽에서 동쪽을 향하여 달무리의 북쪽 고리를 꿰고 또 달 가운데를 꿰고 또 남쪽 고리를 꿰고서 서쪽을 향하여 앞의 끝과 서로 만났다. 그 길이는 하늘 끝까지 닿았고 형상은 긴 고리와 같았는데 이경(二更)에 희미해지다가 사라졌다.’ 하였으므로, 형상을 그려서 올려 보냅니다."하였는데, 상이 이청의 서장(書狀)과 해와 달의 그림을 좌의정 윤인경에게 내어보이고 이르기를,"이달 1일에 일변(日變)이 있었으므로 바야흐로 황공스러운데 이제 또 이러한 재변이 있었으니 더욱 미안하다."하니, 윤인경이 아뢰기를,"재변이 여러번 있으므로 매우 놀랍고 두려우니 천문을 아는 의정부 좌찬성 성세창과 병조 참의 안현(安玹)을 불러 함께 의논하겠습니다."하였다. 성세창 등이 함께 의논하여 아뢰기를,"천문을 살펴보면 운기(雲氣)가 해 위에 있는 것을 관(冠)이라 하는데 그에 대한 재해는 모르겠습니다. 그러나 백기(白氣)가 달을 꿰고 햇무리가 세 겹이고 백기가 태양을 범하였으니 이는 병상(兵象)입니다. 위에서 처음 하시는 정사인데 재변을 부를 잘못이 어디 있겠습니까? 그러나 재변은 헛되이 일어나지 않는 것이니 처음 정사에 더욱 덕을 공경하여 공구 수성(恐懼修省)하소서. 대저 천변(天變)의 발생을 무슨 일의 응보라고 분명히 지적할 수는 없으나 변방의 경보와 방비 등에 대해 각별한 조처를 하는 것이 마땅하겠습니다."하니, 답하기를,"알았다. 변방의 방비에 대한 조처는 해당 관원에게 신칙하도록 하겠다."하였다.',
#   'category': ['행정-지방행정(地方行政)', '정론(政論)', '과학-천기(天氣)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101019_003',
#   'title': '유관·황헌 등에게 관직을 제수하다',
#   'content': ' 유관(柳灌)을 의정부 우의정으로, 황헌(黃憲)을 평안도 관찰사로 삼았다.',
#   'category': ['인사-임면(任免)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101020_001',
#   'title': '조석전을 지내고 상식을 올리다',
#   'content': '조석전을 지내고 상식을 올렸다.',
#   'category': ['왕실(王室)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101020_002',
#   'title': '동지사 정사룡·송인수의 서장을 정원에 내리다',
#   'content': '동지사(冬至使) 정사룡(鄭士龍)·송인수(宋麟壽)의 서장 【＊】 을 정원에 내리면서 전교하였다."이 서장을 좌의정에게 보이라."  【＊서장의 내용은 이러하다."황제는 한 번도 시조(視朝)하지 않고 사천제(祀天祭)도 섭행(攝行)하였습니다. 산서성(山西省) 대동(大同)의 변방 군졸인 왕삼(王三)이 모반(謀叛)하여 달자(㺚子)에게 들어가 오랑캐의 무리를 유인하여 오래도록 변방의 환란을 야기시켰고 전후 사람과 짐승을 죽이고 잡아간 것이 이루 헤아릴 수 없었다고 합니다. 그래서 조정에서 상을 걸고 잡게 한 지 여러해가 되었는데, 왕삼이 동부(同府)의 유복기(劉伏玘)와 서로 알기 때문에 입구(入寇)하여 대동 동성(東城)에 이르러 유복기에게 가서 술을 마셨다고 합니다. 이때 유복기가 풍용(馮龍)·가승(賈昇)·장보(張寶) 등과 복병 2백여 인을 대기시켰다가 같이 꾀하여 포박, 수비지휘(守備指揮) 주당(周堂)에게 고하고 주당이 바삐 아뢰니 황제가 몹시 기뻐하고 조야(朝野)가 다같이 매우 시원하게 여겼다고 합니다. 형부(刑部)가 성지(聖旨)를 받들어 능지처참(凌遲處斬)한 다음 머리를 여러 변방에 돌려 열흘 동안 효수(梟首)하였고, 유복기에게 은 1천 냥을 상주고 풍용·가승·장보 등에게 각각 은 1백 냥을 상주었다고 합니다. 예부(禮部)가 우리 나라가 이왕걸(李王乞) 등을 독촉하여 잡은 공이 있다 하여, 성지를 받들어 ‘은 50냥과 표리(表裏) 네 벌을 상주고 이응성(李應星)에게는 은 10냥과 표리 두 벌을 상주라.’고 하였습니다."】\r\n\t\t\t\t\t\t\r\n\r\n\t\t\t\t\t\t\r\n\t\t\t\t\t\t',
#   'category': ['외교-명(明)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101021_001',
#   'title': '조석전을 지내고 상식을 올리다',
#   'content': '조석전을 지내고 상식을 올렸다.',
#   'category': ['왕실(王室)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101021_002',
#   'title': '좌의정 윤인경 등이 찬선을 들 것을 권하다',
#   'content': ' 좌의정 윤인경 등이 아뢰기를,"전에 듣건대 전혀 찬선을 드시지 않는다 하므로 찬선을 드시기를 청하였던 것인데 마땅히 생각하여 부응토록 하겠다고 전교하였습니다. 그러나 이제까지도 찬선을 드시지 않는다하니 다들 민망하게 생각합니다. 위에서 애통이 지나쳐 종사의 대계를 생각하시지 않으시니 신들은 더욱 민망합니다. 세종 대왕의 유교(遺敎)는 정리와 예문을 참작하여 만든 권제(權制)이므로 대대로 모두 지켜 왔는데, 지금은 애통해 하여 수척하신 것이 예도에 지나쳐 중도를 따르시지 않으므로 ‘수척하되 목숨을 잃게 하지 않고 수척하되 몸을 위태롭게 하지 않는다.’는 말에 어긋납니다. 선왕의 제례(制禮)를 지킴으로써 종사의 대계를 생각하소서."하니, 답하기를,"내가 이 망극한 화(禍)를 만났으므로 애통해 하여 수척한 것이 예도에 지나치더라도 마음에 미흡한데, 더구나 무슨 지나치게 애통해 한 일이 있기에 아뢰는 말을 여러번 듣게 되는가. 놀랍고 부끄러움을 견딜 수 없다."하였다. 또 아뢰기를,"신은 밖에 있으므로 천안(天顔)을 우러르지 못하였으나 보름날 배제(陪祭)055)  할 때에 시종(侍從)들이 ‘상의 옥체가 매우 쇠약하여 걸음도 전만 못하다.’ 하기에, 놀랍고 염려됨을 견딜 수 없었습니다. 위에서 애통 망극하신 정이 그지없기는 하시지만 선왕의 제례는 지키지 않을 수 없습니다. 예문에 ‘상중(喪中)에 있을 때에 병이 생기면 술도 마시고 고기도 먹되 병이 나으면 처음으로 되돌아간다.’는 말이 있는데 진실로 병이 생기면 술과 고기도 쓸 수 있거든 더구나 찬선을 드시는 것이겠습니까. 삼가 종사의 대계를 위하여 애써 찬선을 드소서."하니, 답하기를,"반복하여 진언하니 더욱 황공하다. 따르도록 하겠다."하였다. 윤인경 등이 또 대비(大妃)에게 아뢰기를,"듣건대 주상께서 애통해 하여 수척한 것이 도에 지나쳐 기운이 아주 쇠약하시다 합니다. 신들이 아뢰지 않더라도 위에서 옥체를 보호하시는 데에 그 방도를 극진하게 하실 것이지만 발인(發引)할 날짜가 촉박한데 조금이라도 편찮으신 데가 있으면 일이 더욱 당혹스럽게 될 것이니, 찬선을 드시도록 권하여 반드시 옥체의 강녕을 보전하게 하소서. 상전(上殿)의 말씀은 위에서도 반드시 들으실 것입니다."하니, 대비가 답하기를,"나도 매번 사람을 시켜 찬선(饌膳)을 권하고 드시는 음식이 있으면 가져오게 하여 살펴 보는 등 매양 유념하고 있다. 지난번 감기로 말미암아 자못 기침기가 있으므로 곡전(哭奠)을 거행하지 말도록 청하였으나 거행하여 마지않으니, 나도 민망하고 염려스럽다."하였다.',
#   'category': ['왕실(王室)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101021_003',
#   'title': '간원이 어용 그리는 것을 멈출 것을 청하다',
#   'content': '간원이 아뢰기를,"어용(御容)을 본떠 그리는 것이 조종 때의 고사(古事)이기는 합니다. 그러나 평소에 위에서 그리도록 명하셨다면 그만이지만, 승하하신 뒤에 추상(追想)하여 그리게 하면 조석으로 곁에서 모시던 사람이 그리더라도 진용과 어긋나는 데가 많을 것인데 더구나 밖에 있던 사람은 우러른 일이 매우 드문데이겠습니까? 두서너 대신(大臣)을 시켜 지휘하여 그리는 것을 살피게 하더라도 만분의 일도 비슷하지 못할 것입니다. 선유(先儒)가   영당(影堂) 영당(影堂)056)  에 대한 일을 논하면서 ‘터럭만큼이라도 닮지 않으면 곧 내 부모가 아니다.’라는 말을 하였는데 닮지 않은 사진을 어버이로 여겨 높여 받드는 것은 효자가 추원(追遠)하는 정성에 매우 어긋나니, 대행 대왕의 어용을 그리는 것을 멈추도록 명하소서."하니, 답하기를,"대행 대왕의 어용을 그리는 일은 예전의 규례도 그러하기 때문에 시킨 것인데 아뢴 말이 이러하니 대신과 다시 의논하겠다."하고, 정원에 전교하기를,"내일 아침 이에 대해 대신과 의논하라."하였다.',
#   'category': ['왕실(王室)', '정론-간쟁(諫諍)', '예술-미술(美術)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10101022_001',
#   'title': '조석전을 지내고 상식을 올리다',
#   'content': '상이 조석전을 지내고 상식을 올렸다.',
#   'category': ['왕실(王室)']},
# ...
#   'category': ['왕실-비빈(妃嬪)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10107002_007',
#   'title': '소렴이 끝나고 전례를 지내다',
#   'content': '미시(未時)에 소렴이 끝나고 전례(奠禮)를 지냈다.',
#   'category': ['왕실-의식(儀式)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10107002_008',
#   'title': '대군 부인이 입궐하다',
#   'content': '유시(酉時)에 대군 부인(大君夫人)  【 별좌(別坐) 심강(沈鋼)의 딸이고 참판(參判) 심연원(沈連源)의 손녀이다.】 이 입궐(入闕)하였다.',
#   'category': ['왕실-종친(宗親)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10107002_009',
#   'title': '경성에 밤에 소동이 일어나다',
#   'content': ' 경성(京城)에 밤에 소동이 있었다. 【상께서 승하하시던 날에 경중(京中) 사람들이 스스로 경동(驚動)하여 뭇사람이 요사한 말을 퍼뜨리기를 ‘괴물이 밤에 다니는데 지나가는 곳에는 검은 기운이 캄캄하고 뭇수레가 가는 듯한 소리가 난다.’ 하였다. 서로 전하여 미친 듯이 현혹되어 떼를 지어 모여서 함께 떠들고 궐하(闕下)로부터 네거리까지 징을 치며 쫓으니 소리는 성안을 진동하고 인마(人馬)가 놀라 피해 다니는데 순졸(巡卒)이 막을 수 없었다. 이와 같이 3∼4일 계속 된 후에 그쳤다.】\r\n\t\t\t\t\t\t\r\n\r\n\t\t\t\t\t\t\r\n\t\t\t\t\t\t',
#   'category': ['사법-치안(治安)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10107003_001',
#   'title': '영의정 윤인경 등이 대비전에 중전이 미음을 들도록 권하라고 아뢰다',
#   'content': ' 영의정 윤인경, 좌의정 유관이 대비전(大妃殿)에 아뢰기를,"중전께서 지나치게 슬퍼하여 전혀 미음을 드시지 않는다 합니다. 나라의 운수가 이렇게 되어, 중종의 상에 소상(小祥)을 지내기 전에 또 곧 이 일이 있고 겨우 중국 사신이 다녀가고 상사도 치르지 못하였는데, 중전께서 지나치게 슬퍼하시면 반드시 생명을 손상하시게 될 것입니다. 아래에서 아뢰는 것을 중전께서 따르지 않으시니, 위에서 애써 미음을 권하시면 생명을 손상하게 되지는 않을 것입니다."하니, 답하기를,"내가 복이 없어 지난해에 대환(大患)을 만나고도 죽지 않고 살았는데 또 뜻밖에 이렇게 되니, 정신이 어두워서 어찌할 바를 모르므로 나라의 일을 헤아릴 수 없어 뭐라고 말할 것이 없다. 어찌 이러한 때가 있는가. 나라의 일을 감당할 수 없는 형세이니 답답하고 염려되기 그지없다. 중궁(中宮)은 내가 밤낮으로 떠나지 않고 죽을 권하나, 저렇듯 지나치게 슬퍼하여 따르려 하지 않는다. 그러나 어제부터 죽을 들도록 타일렀는데 나도 마음이 어지러워 어찌할 바를 모르겠다."하였다. 윤인경 등이 회계하기를,"비망기(備忘記)463)  를 보옵건대 신들의 심정이 망극합니다마는, 위에서 다시 애써 권하셔야 하겠습니다. 상전(上殿)이 아니면 달리 바랄 수 없겠습니다."하였다.',
#   'category': ['왕실-비빈(妃嬪)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10107003_002',
#   'title': '중전이 빈전 도감에 비현각으로 옮길 뜻을 전교하다',
#   'content': '중전이 빈전 도감(殯殿都監)에 전교하기를,"대행왕은 사정전(思政殿)에 빈소를 모셨는데 내가 있는 곳은 멀리 떨어졌으니, 비현각(丕顯閣)으로 옮아 들어가려 한다."하였는데, 곧 영의정 윤인경, 좌의정 유관이 비현각에 들어가 살피고, 이어서 중전에게 아뢰기를,"나라의 운수가 이렇게 되어 중종의 상에 소상을 지내기 전에 또 일이 있습니다. 이제 듣건대 전혀 미음을 드시지 않는다 하니 이렇게 하시면 반드시 생명을 손상하게 될 것입니다. 중종의 상 때부터 산릉(山陵)과 중국 사신의 일에 백성의 생계가 탕진되었으므로 대행왕께서 병환이 위독하신데도 ‘백성이 마침내 어떻게 되겠는가?’ 하셨습니다. 중전께서는 비록 스스로 아끼지 않더라도, 백성을 위하여 스스로 보중하는 것이 어떠하겠습니까? 조종(祖宗)의 유교(遺敎)에도 ‘초상 이튿날에 죽을 마시고 사흘째에는 수라를 들라.’ 하였거니와, 더구나 이제 상전께서 힘껏 권하시는데, 어찌 따르지 않을 수 있겠습니까. 대행왕께서 초상 때에도 상전의 분부에 대해서는 반드시 애써 따르신 것을 위464)  에서 친히 보셨으니, 애써 따르소서.또 비현각으로 옮기려 한다는 말씀을 듣고 신들이 들어가 살펴보니, 외처(外處)에 가까와서 늘 계실 수 없겠습니다. 중종께서 훙서(薨逝)하시자 통명전(通明殿)465)  에 빈소를 모셨는데, 한때의 의논이 그르게 여겼습니다. 상사는 예문(禮文)에 따라야 하는데, 내처(內處)에 어찌 빈전(殯殿)에 가깝고 늘 계 실 곳이 없겠습니까. 비현각을 상차(喪次)로 삼되 때때로 나가 계시는 것이 어떠하겠습니까?"하니, 답하기를,"대행왕의 효성은 천성에서 나왔으므로, 질병에 걸리셨더라도 하늘에 계신 조종의 영(靈)이 도우시리라 바랐는데, 모시는 사람이 복이 없이 마침내 이러한 일을 만났으니, 살아 무엇하겠는가. 중종의 초상에 대행왕께서 산발(散髮)하기 전에는 수라를 드시지 않았으니, 나도 이에 따라서 하려 한다. 대행왕께서 임종 때에, 종효(終孝)하지 못한 것을 매우 슬퍼하셨고, 또 상장(喪葬)에 관한 일로 정승에게 분부가 계셨으나, 마음이 어지러워서 곧 써서 내리지 못하였다. 비현각에 때때로 거처하는 일은 아뢴 대로 하라."하였다. 윤인경 등이 또 아뢰기를,"위466)  에서 정리(情理)가 어찌 망극하시지 않겠습니까마는, 모든 일을 널리 생각하여 스스로 잘 보호하여 상례(喪禮)를 치르셔야 하는데, 미음을 들지 않으면 어찌 생명을 손상하지 않겠습니까. 상장을 유교(遺敎)하신 일을 빨리 써서 내리소서."하였다.',
#   'category': ['왕실-종사(宗社)', '왕실-비빈(妃嬪)', '왕실-의식(儀式)', '왕실-국왕(國王)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10107003_003',
#   'title': '영의정 등이 대군에게 미음을 들 것을 청하다',
#   'content': ' 영의정 윤인경·좌의정 유관이 대군(大君)에게 아뢰기를,"조종의 유교에, 초상 이튿날에 미음을 들라 하셨는데, 이제 이미 사흘째 되는 날이니, 미음을 드소서."하니, 답하기를,"망극한 중이나 나라의 일을 생각하여 따르겠다."하였다.',
#   'category': ['왕실-종친(宗親)', '왕실-의식(儀式)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10107003_004',
#   'title': '중전이 윤인경에게 전교하다',
#   'content': '중전이 윤인경 등에게 전교하기를,"유교를 써서 내리려 하나 망극하여 살피지 못하겠으니, 천천히 써서 내리겠다. 수라는 지금 어찌 들 수 있겠는가. 성복(成服)한 뒤에 들겠다."하니, 【영상 등은 미음을 아뢰었는데 승전색이 수라로 잘못 아뢰었으므로, 답교(答敎)가 이러하였다.】  윤인경 등이 회계하기를,"신들이 감히 찬선(饌膳)을 드시기를 바란 것이 아니라, 미음을 드시기를 바란 것입니다. 대행왕께서 초상에 지나치게 슬퍼하셨으므로 이렇게 되신 것은 중전께서 친히 보신 바이고 신들이 애통해 하는 바입니다. 대행왕께서도 상전의 분부에 대해서는 반드시 따르셨으니, 상전의 분부를 거역하지 말고 애써 미음을 드소서."하였다.',
#   'category': ['왕실-비빈(妃嬪)', '왕실-의식(儀式)', '왕실-국왕(國王)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10107004_001',
#   'title': '영의정 윤인경 등이 대비에게 대렴할 것을 청하다',
#   'content': ' 영의정 윤인경(尹仁鏡), 좌의정 유관(柳灌), 병조 판서 이기(李芑), 좌찬성 이언적(李彦迪), 이조 판서 유인숙(柳仁淑), 우찬성 권벌(權橃), 우참찬 정옥형(丁玉亨), 공조 판서 허자(許磁), 호조 판서 임백령(林百齡), 예조 판서 윤개(尹漑), 대사헌 민제인(閔齊仁), 이조 참판 신거관(愼居寬), 대사간 구수담(具壽聃), 부제학 나숙(羅淑), 좌승지 최연(崔演)이 대비(大妃)에게 아뢰기를,"대렴(大斂)은 예문에 따라서 내일 해야 할 것이나, 이제 소렴한 의대(衣襨)에 습기가 있다 하는데 이것은 큰일이니, 하는 수 없이 오늘 대렴하려 합니다. 날씨가 매우 덥고 이제 이미 나흘째 되는 날이니, 다시 내일을 기다릴 수 없겠습니다. 오늘을 지내면 미안한 일이 있을 것이 염려되므로 감히 아룁니다."하니, 답하기를,"예문을 어기는 듯하나, 하는 것이 마땅하다."하였다.',
#   'category': ['왕실-의식(儀式)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10107004_002',
#   'title': '유관이 대렴에 대해 아뢰다',
#   'content': '        유관이 아뢰기를,"대렴 때에는 총호사(摠護使)와 빈전 도감(殯殿都監)의 당상(堂上)·낭관(郞官)과 도승지(都承旨)·색승지(色承旨)와 사관(史官) 등이 들어가 보아야 합니다."하고, 재궁(梓宮)467)                  에 들일 때에는 수상(首相)도 들어가야 한다는 것을 아뢰니, 대비가 총호사에게 전교하기를,"중종의 상 때에는 염(斂)이 끝난 뒤에 총호사 등이 들어가 보았으니, 이제도 이 예(禮)에 따라서 하라."                  사신은 논한다. 한 번 잘못한 전례를 끌어대어 들어가 보지 않고, 송종(送終)의 대례(大禮)를 궁인(宮人)의 손에 맡겼으니, 상례(喪禮)를 제도대로 하지 않은 것을 알 수 있다.',
#   'category': ['왕실-의식(儀式)', '행정-중앙행정(中央行政)', '역사-사학(史學)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10107004_003',
#   'title': '중전이 대행왕의 유교를 언문으로 써서 내려 보이다',
#   'content': '중전이 대행왕이 임종할 때에 유교한 것을 언문(諺文)으로 써서 유관 등에게 내려 보이니, 유관 등이 보고 다들 통곡하였다. 곧 이덕응(李德應)으로 하여금 봉함하게 하고 송기수(宋麒壽)로 하여금 서명하게 하고 말하기를,"염이 끝나거든 윤인경에게 내어 보여야 하겠다."하고, 유관이 또 말하기를,"유교에, 송종의 모든 일은 일체 소박하게 하며 백성의 폐해를 덜라 하셨는데, 이것은 분부대로 시행하여 그 아름다움을 성취시키지 않아서는 안 되겠다."하였다.',
#   'category': ['왕실-비빈(妃嬪)', '왕실-의식(儀式)', '왕실-국왕(國王)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10107004_004',
#   'title': '염이 끝나고 전례를 지내다',
#   'content': '염이 끝나자, 유관 등이 들어가 보고는 가슴을 치고 발을 구르며 통곡하고 나왔다. 내시(內侍)가 드디어 염상(斂床)을 들고 사정전(思政殿)에 있는 재궁 앞에 이르니, 윤인경과 도감(都監) 등이 살펴서 재궁에 넣은 다음 드디어 전례(奠禮)를 지냈다.',
#   'category': ['왕실-의식(儀式)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10107004_005',
#   'title': '성빈하고 전례를 지내다',
#   'content': '술시(戌時)에 성빈(成殯)468)  이 끝나고 전례를 지냈다.',
#   'category': ['왕실-의식(儀式)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10107004_006',
#   'title': '조정에 공포한 대행왕의 유교',
#   'content': ' 영의정 윤인경이, 중전이 언문으로 쓴 대행왕의 유교를 주서(注書) 안함(安馠)에게 주어 승정원(承政院)에 보이니, 승지(承旨)·사관(史官) 등이 둘러 앉아 펴서 읽고 누구나 다 통곡하였다. 곧 문자로써 번역하여 별지에 써서 조정(朝廷)에 공포하였는데 그 글에 이르기를,"대행왕께서 임종 때에 전교하기를 ‘내가 우연히 이 병을 얻어서 부왕(父王)께 종효(終孝)하지 못하게 되었으니, 망극한 심정을 어떻게 죄다 말할 수 있겠는가. 산릉(山陵)은 백성의 폐해를 덜도록 힘쓰고 반드시 부왕과 모후(母后) 두 능의 근처에 써야 한다. 상장(喪葬)의 모든 일은 되도록 소박하게 하고 상례도 일체 예문을 따르게 해야 한다. 내가 죽었다고 생각하지 말고, 말할 일이 있거든 반드시 대신에게 의논하여 일체 그 말을 들어야 한다. 동궁(東宮)에 있을 때부터 오래 있던 사부(師傅)와 요속(僚屬)도 많이 있으니, 어찌 내 뜻을 아는 사람이 없겠는가. 송종(送終)하는 모든 일은 절대로 사치하지 말도록 하라.’ 하셨는데, 반복하여 백성의 폐해를 더는 것을 생각하고 전교하셨다. 망극한 중에 전교하신 것을 들었으므로 죄다 기억하지 못하여 대강만을 전한다."하였다. 이어서 전교하기를,"나도 어찌 오래 살 수 있겠는가. 위급하게 되면 어느 겨를에 처리할 일을 알리겠는가. 대행왕의 능소(陵所)를 정한 뒤에 그 같은 언덕 안에 나를 묻을 곳도 아울러 정하는 것이 내 지극한 바람이다. 대행왕을 위하여 정한 경역이 길면 상당(上堂)·하당(下堂)을 만들어야 할 것이고, 모자란다면 합장(合葬)하는 것도 전례가 있다."하였다.  사신은 논한다. 아, 애통하다. 대행왕의 유교를 차마 볼 수 있으랴. 백성을 사랑하는 염려를 성회(聖懷)에서 늦추지 아니하여 병환이 위독하신데도 한탄하여 ‘백성이 마침내 어떻게 되겠는가?’ 하고, 훙서할 때에도 백성의 폐해를 덜라고 분부하셨으니, 대개 중종의 상이 있고 나서 산릉의 일이 겨우 끝나자, 잇달아 네 중국 사신의 일로 온 나라 백성의 재력(財力)이 이미 다한 데에 성념(聖念)이 근간(懃懇)하여 마지않았으니 어찌 이 때문에 더욱이 마음이 타지 않았겠는가. 하늘이 나이를 더 주어 그 인심(仁心)·인정(仁政)을 우리 동방에 크게 펴게 하였다면, 그 치화(治化)를 어찌 헤아릴 수 있겠는가. 하늘이 동방을 돕지 아니하여 우리 백성이 지치(至治)의 은택을 입지 못하게 하였다. 아, 애통하다.  또 사신은 논한다. 훙서할 때에 ‘일체 예문을 따르라.’고 훈계한 까닭은 어찌 나라의 일이 예(禮)에 어긋나는 것이 심한 것을 늘 보았고 중종의 상 때에 어긋난 일이 더욱 많아 깊이 한탄한 나머지 이렇게 분부한 것이 아니겠는가. 아, 대렴·소렴을 미리 하고도 염하는 것을 돌보지 않고 궁인에게 맡겼으니, 조정에 있는 신하가 그 분부를 저버리지 않았다고 할 수 있겠는가.  또 사신은 논한다. 대행왕은 평시에 눕거나 기대어 피로해 졸은 적이 없고 늘 한 방에 바로 앉아 있는 것이 담담하여 마치 서생(書生)같았고 편찮을 때에도 조금도 게을리하지 않았는데, 증세가 위증하여져서야 비로소 눕기도 하고 앉기도 하였으므로 측근의 신하들이 비로소 그 병환이 깊어진 것을 알았다. 경회루(慶會樓)에 벼락치던 날에는 대행왕의 증세가 이미 위독하였는데, 측근 신하가 ‘놀라지 않으셨습니까?’ 하고 물었으니 ‘마음이 안정된 지 이미 오랜데 무슨 놀랄 것이 있겠는가.’ 하고, 또 ‘어느 곳에 벼락이 쳤느냐?’고 묻자, 측근 신하가 성려(聖慮)를 놀라게 할 것이 염려되어 숨겨서 말하기를 서쪽에 벼락이 친 듯하나 아직은 확실히 알지 못하겠습니다.’ 하니 ‘미안하다는 뜻을 재상에게 말하고 싶다.’ 하였다. 또 늘 측근 신하에게 말하기를 ‘음식을 조절하고 약을 먹으면 권제(權制)를 따르지 않더라도 지탱할 수 있으리라고 생각하였는데, 마침내 이 지경에 이르게 되었다. 이제 권제를 따르더라도 무슨 보탬이 되겠느냐.’ 하였고, 정신을 잃게 되어서는 스스로 헛소리를 하였는데, 번번이 경연(經筵)에 관한 일을 말하거나 청강(聽講)하지 못하는 것을 한탄하는 소리였다. 초하룻날 밤 기절하였다가 되살아났을 때에 정염(鄭𥖝)이 들어가 진맥(診脈)하려는데 궁인(宮人)이 손을 끌어내니, 대행왕이 이미 말은 못하게 되었으나 마음속에는 매우 싫어하는 듯이 손을 움츠리고 내놓지 않았다. 윤임(尹任)이 곁에 있다가 그 뜻을 알고서 궁인을 뿌리쳐 보내고 나아가 손을 끌어내니, 정염이 그제야 진찰하였다. 아, 이 몇 가지 작은 일로도 대행왕의 수양이 크다는 것을 알 수 있다.',
#   'category': ['왕실-의식(儀式)', '왕실-국왕(國王)', '역사-사학(史學)', '어문학(語文學)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10107005_001',
#   'title': '백관이 곡림을 멈추다',
#   'content': '백관(百官)이 곡림(哭臨)을 멈추었다.  사신은 논한다. 의주(儀註)에 ‘닷새째 되는 날에 성빈(成殯)하고는 곡림하지 않는다 하였다. 이제 성빈을 나흘 만에 미리 행하였으므로, 조정이 의논하여 닷새 만에 조곡(朝哭)하고 그치려 하였는데, 이날 아침에 이르러서는 비가 조금 뿌린다 하여 도로 파하고 고하지 않았다. 아, 신하의 정리(情理)로써 말하면 어찌 닷새의 곡에만 그치겠으며, 어지 조금 오는 비의 습기를 꺼릴 것인가. 곡하려다가 곡하지 않았으니 정성이 희박하다.',
#   'category': ['왕실-의식(儀式)', '역사-사학(史學)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10107005_002',
#   'title': '대비가 영의정에게 산릉에 대해 전교하다',
#   'content': '대비가 영의정 등에게 전교하기를,"대행왕의 유교가 저러하니, 산릉을 복정(卜定)할 때에는 정릉(靖陵) 근처에서 먼저 살펴야 하겠다."하니, 회계하기를,"하교하시지 않더라도 신들도 먼저 살피려 하였습니다."하였다.',
#   'category': ['왕실-의식(儀式)', '왕실-국왕(國王)', '과학-지학(地學)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10107005_003',
#   'title': '영의정 윤인경 등이 대군에게 성복 등 상례에 대해 서계하다',
#   'content': ' 영의정 윤인경(尹仁鏡), 좌의정 유관(柳灌), 병조 판서 이기(李芑), 좌찬성 이언적(李彦迪), 이조 판서 유인숙(柳仁淑), 우찬성 권벌(權橃), 좌참찬 정옥형(丁玉亨), 공조 판서 허자(許磁), 우참찬 신광한(申光漢), 예조 판서 윤개(尹漑), 대사간 구수담(具壽聃), 부제학 나숙(羅淑), 집의 송희규(宋希奎)가 대군(大君)에게 서계(書啓)하기를,"신들이 《춘추(春秋)》의 의리를 살피옵건대, 아버지가 죽으면 아들이 계승하고 형이 죽으면 아우가 계승하니, 명호(名號)는 같지 않을지라도 그 세습(世襲)이 되는 것은 한 가지입니다. 이미 나라를 주었으면, 전해 받은 사람은 그 아들이 아니라도 아들의 도리가 있고, 전한 사람은 그 아버지가 아니라도 아버지의 도리와 같은 것입니다.이제 대행 대왕(大行大王)께서 이미 유교(遺敎)하여 대군에게 전위(傳位)하였으므로 아버지의 도리가 있으니, 대군께서는 아들의 도리를 다하셔야 하며, 모든 상제(喪制)는 한결같이 예문(禮文)대로 하셔야 합니다. 대군께서 이미 대행왕(大行王)에게 아들의 도리를 다하였으면, 왕비(王妃)에게도 마땅히 어머니로 섬겨서 효도를 다하여야 합니다."하고, 이어서 아뢰기를,"형제의 명분이 있기는 하나, 군신·부자의 도리가 크니, 이 뜻을 알아서 상례를 다하셔야 합니다. 내일은 또한 제복(除服)하는 날이니, 늘 이것을 유념하시면 다행이겠습니다."하니,【 윤인경이 막 아뢰고 승전색(承傳色)에게 묻기를 ‘대군께서 능히 글을 아시는가?’ 하였는데, 아신다고 말하니, 윤인경 등이 기뻐하는 빛이 있었다. 이 때 윤인경이 또 일을 아는 내관(內官)으로 대군을 모시는 몇 사람을 불러서   성복(成服)469)  때와 사위(嗣位) 때의 의례(儀禮)를 고하게 하였는데, 내관이 말하기를 ‘듣건대, 내의(內意)는 대군께서 역질(疫疾)을 앓으신 지 오래지 않아서 기운이 아직 쇠약하므로 성복에 내어 보내지 않으려 하신다 한다.’ 하므로, 유관이 말하기를 ‘조석(朝夕)의 곡림(哭臨)은 이미 임시변통으로 멈추었으나, 내일의 성복은 대례(大禮)이니, 행하지 않아서는 안 된다. 행하지 않으면, 계사(繼嗣)하는 뜻이 없을 것이다.’ 하니, 내관이 말하기를 ‘확실히 알지는 못하지만, 전해 들은 내의(內意)가 이러할 뿐이다.’ 하였다. 윤인경이 굳이 변명하려다가 못하고 다만 ‘내일 苣 ?··’ 하면서 머뭇거리고 말을 꺼내지 못했는데 예조 판서 윤개가 말하기를 ‘그렇다면, 성복 때에 나오실 것인지를 빨리 여쭈어야 하겠다.’ 하였다.】  대군이 비망기(備忘記)로 윤인경 등에게 답하기를,"아들의 도리를 다하는 것은 과인(寡人)의 뜻에도 그지없다. 그러나 지금 나이가 어리고 또 역질을 겪은 지 오래지 않으므로 곡림하는 모든 일을 뜻대로 하지 못하였으니, 지극히 미안하다. 그러나 다른 일은 극진히 할 생각이다."하였다. 【이때 우찬성 권벌이 들어가 윤인경에게 고하기를 ‘대군께서 내일 성복에 나오시지 않는다 하니, 이것은 크게 관계되는 일로서 행하지 않으면 사위(嗣位)하는 처음에 인심을 수합하는 것을 급선무로 삼아야 하니, 대신이 아뢰지 않아서는 안 된다. 또, 지난 겨울 12월에 역질을 앓고 이제는 이미 오래 되었는데, 무엇이 구애되겠는가.’ 하였다. 윤인경이 아뢰려 하는데, 호조 판서 임백령이 말하기를 ‘비망기에 극진히 할 생각이라고 말씀하고 성복하지 않는다는 말씀을 하지 않으셨으니, 먼저 여쭈고 뒤에 아뢰는 것이 어떠하겠는가?’ 하고, 권벌이 말하기를 ‘일찍 결단하는 것만 못하니, 빨리 아뢰어야 한다.’ 하니 윤인경이 그제야 드디어 아뢰었다.】  윤인경 등이 아뢰기를,"여느 때에는 혹 예문대로 따르지 않기도 하나, 내일의 성복으로 말하면 예절의 큰 것이니 반드시 성복해야 사위하고 수하(受賀)하는 예가 완전해질 것이고 온 나라 신민의 마음이 정해질 것입니다. 그렇지 않으면 큰 예가 완전해지지 않고 인심이 정해지지 않을 것인데, 이제 바야흐로 인심을 수합할 때이니, 유념하지 않으시면 안 되겠습니다."하니, 답하기를,"역질을 겪은 지 오래지 않으니 이 때문에 미안하다. 모두의 뜻이 이러하니, 성복하는 모든 예를 죄다 거행하겠다."하였다.',
#   'category': ['왕실-종친(宗親)', '왕실-의식(儀式)', '왕실-국왕(國王)', '정론-정론(政論)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10107005_004',
#   'title': '영의정 윤인경 등이 중전에게 조섭할 것을 아뢰다',
#   'content': ' 영의정 윤인경 등이 중전에게 아뢰기를,"유교(遺敎)를 보고 통곡하여 마지않았습니다. 상례를 되도록 소박하게 하라고 하셨는데, 이는 임금의 심상한 덕이 아니니 마땅히 분부대로 해야 할 것이며, 위470)  에서 산릉(山陵)을 널리 살피라고 전교하신 일도 분부대로 해야 하겠습니다. 이제 듣건대 위에서 전혀 미음을 드시지 않는다 하니 답답하고 염려되기 그지 없습니다. 스스로 조보(調保)하여 상례를 치르셔야 하겠습니다."하니, 답하기를,"아뢴 뜻은 알았다. 미음을 어찌 들지 않겠는가. 대비께서 힘써 권하시므로 여러 번 들었다."하였다.  사신은 논한다. 이때 중전에게 구역하는 증세가 있어서 호초(胡椒)를 씹으려 하였으나, 대내(大內)에 저축된 것이 없어서 약방(藥房)에 영을 내려 바치게 하였다. 아, 한 나라의 임금으로서 한 번 씹을 호초의 저축이 없었으니, 사사로이 저장하지 않았다는 것을 이것으로 알 수 있다. 대행왕의 덕이 지극하다.',
#   'category': ['왕실-비빈(妃嬪)',
#    '왕실-의식(儀式)',
#    '왕실-국왕(國王)',
#    '역사-사학(史學)',
#    '과학-지학(地學)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10107006_001',
#   'title': '진시에 의례대로 성복하다',
#   'content': '진시(辰時)에 의례대로 성복하였다.',
#   'category': ['왕실-국왕(國王)', '왕실-의식(儀式)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10107006_002',
#   'title': '유생이 광화문 밖에서 곡림하다',
#   'content': '유생(儒生)이 광화문 밖에서 곡림(哭臨)하였다.  사신은 논한다. 승하하시던 날에 도하(都下)의 유생이 각각 소식을 듣고 선후하여 궐하(闕下)에 달려와서 통곡하는 것이 밤이 되어도 끊이지 않고, 미천한 지아비와 지어미까지도 거리를 메우고 길을 메워 누구나 다 가슴을 치고 슬퍼하였다. 대행왕이 훙서에 임박하여 기절하였다가 되살아난 것이 두어 번인데, 민간에게 듣고는 궐하에서 골목까지 어른 아이 없이 모두 손을 모아 하늘에 빌었다. 이날에 이르러 유생이 또 궐외(闕外)에서 곡하여 다들 그 슬픔을 다하였다. 아, 허다한 유생이 어찌 죄다 군자다운 사람이었겠으며, 미천한 지아비와 지어미도 누가 시켜서 그렇게 한 것이겠는가. 즉위한 지 한 해가 못되었는데 인심이 이러하니, 덕이 사람을 감동시키기 쉽고 사람에게 깊이 들어간다는 것을 알 수 있다.',
#   'category': ['왕실-의식(儀式)', '왕실-국왕(國王)', '사상-유학(儒學)', '역사-사학(史學)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10107006_003',
#   'title': '미시에 사왕이 근정전에서 즉위하다',
#   'content': '미시(未時)에 사왕(嗣王)이 면복(冕服)을 갖추고 여차(廬次)에서 나와 사정전(思政殿)의 동쪽 뜰에 있는 욕위(褥位)에 나아가 꿇어앉아, 사향(司香)이 향을 올린 뒤에 사배(四拜)하고 나서, 동쪽 섬돌로부터 올라가 향안(香案) 앞에 나아가 꿇어앉았다. 영의정 윤인경이 유교를 받들고 나와서 사왕에게 주니 사왕이 유교를 받아서 보고 나서 도승지 송기수에게 주고, 좌의정 유관이 대보(大寶)를 받들고 나와서 사왕에게 주니 사왕이 받아서 좌승지 최연(崔演)에게 주었다. 왕이 동쪽 뜰에 있는 욕위로 내려가 사배하고 나서, 사정문(思政門) 밖에 있는 악차(幄次)로 나갔다. 통례원(通禮院)이 백관(百官)의 반열(班列)이 정제되었음을 고하자, 왕이 악차에게 나와 여(輿)를 타고 나와서 근정문(勤政門)에서 즉위하였다. 백관이 사배삼고두(四拜三叩頭)하고 산호(山呼)471)  하고 또 사배하고 나서 상이 대내(大內)로 돌아와 면복을 벗었다.',
#   'category': ['왕실-의식(儀式)', '왕실-국왕(國王)', '의생활(衣生活)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10107006_004',
#   'title': '동부승지 이윤경이 교서 반포에 대해 아뢰다',
#   'content': ' 동부승지(同副承旨) 이윤경(李潤慶)이 아뢰기를,"즉위하면 반드시 교서(敎書)를 반포해야 하고, 조종(祖宗)께서 교서를 반포하실 때에는 으레 사문(赦文)이 있었는데, 이제는 어찌해야 합니까?"하니, 전교하기를,"전례를 써서 아뢰라."하였다. 이윤경이 전례를 쓴 단자를 입계(入啓)하니, 전교하기를,"근래 자주 사유(赦宥)하여 미안한 듯하나, 조종 때에 으레 이렇게 하였으니, 성종(成宗) 때의 전례대로 하도록 하라."하였다.',
#   'category': ['왕실-의식(儀式)', '왕실-국왕(國王)', '사법(司法)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10107006_005',
#   'title': '사인 이천계가 교서의 내용에 관해 아뢰다',
#   'content': ' 사인(舍人) 이천계(李天啓)가 영상·좌상의 뜻으로 아뢰기를,"사유 교서에 ‘관계강상(關係綱常)·장오(贓汚)472)   이외’라는 글이 없는데, 강상은 큰 일이거니와 장오도 쉽사리 놓아 줄 수 없으니, 전례가 그러하더라도 이제는 아울러 적지 않아서는 안 되겠습니다."하니, 알았다고 전교하였다.',
#   'category': ['사법(司法)']},
#  {'url': 'http://sillok.history.go.kr/id/kla_10107006_006',
#   'title': '사유를 반포하다',
#   'content': '사유를 반포하였다. 그 교서는 이러하다."하늘이 하국(下國)에 재앙을 일으킨 것이 이때보다 심한 적이 없으니, 나라가 상천(上天)에 죄를 얻은 것이 어찌하여 이런 극도에 이르렀는가. 우러러 울부짖어도 미치지 못하고 어루만져 억눌러도 되살아난다. 생각하건대, 우리 대행 대왕께서는 덕은 태어나면서 슬기롭고 효는 날 때부터 도타우셨으므로, 동궁(東宮)에 계신던 25년 동안에 늘 학문에 종사하여 시종 변하지 않았고, 침문(寢門)에 이르러 하루에 세 번 뵈어 찬선(饌膳)을 보살피고 늘 한난(寒煖)을 물으셨으며, 친족을 우애하는 마음이 있어 동기(同氣)가 흉액에 걸린 것을 풀어주고, 예(禮)로 사람에게 겸손하여 많은 선비들의 귀복(歸服)함을 얻으셨다. 선왕께서 부탁하신 바요 조종께서 의뢰하신 바인데, 어찌하여 천명이 길지 아니하여 해독이 모여들었는가. 그 훌륭한 통서(統緖)를 이었더라도 참으로 많은 어려움을 감당하지 못하였다. 사람들이 바야흐로 덕화(德化)가 이룩되는 것을 보려 하였는데, 하늘은 마치 지치(至治)의 회복을 바라지 않는 듯하였다. 재앙을 준 것을 뉘우치지 않고 어찌하여 나에게 잔인한가.그래서 위독한 병환 중에도 후계 문제를 잊지 않고 이 어린 아우를 생각하여 빨리 승조(承祧)473)  를 명하셨다. 슬픔이 마음에 절박하고 말씀이 귓전에 있으나, 믿는 바를 이미 잃었으니 또한 장차 누구를 따르겠는가. 이에 유교(遺敎)를 받은 신하가 중대한 부탁을 함께 도왔다. 마지못해 즉위하는 것을 슬퍼하고 애써 유명(遺命)을 따르는 것을 통탄하면서 가정(嘉靖) 24년 7월 6일 병인에 경복궁(景福宮)의 근정문(勤政門)에서 즉위하여, 왕대비(王大妃)를 대왕 대비(大王大妃)로 높이고, 왕비를 대왕비로 높이고, 부인(夫人) 심씨(沈氏)를 왕비로 삼는다. 이미 크고 어려운 사업이 어린 이 몸에 끼쳐졌으니, 왕명을 선포하여 원근에 은택을 베푼다.이날 어둑새벽 이전의 모반 대역(謀反大逆)·모반(謀叛)·자손 모살구 매조부모부모(子孫謀殺毆罵祖父母父母)·처첩 모살부(妻妾謀殺夫)·노비 모살주(奴婢謀殺主)·고독(蠱毒)·염매(魘魅)·모고살인(謀故殺人)·관계강상(關係綱常)·장오(贓汚)·강도(强盜)를 제외한 죄는 이미 발각되었건 발각되지 않았건 이미 결정(決正)하였건 결정하지 않았건 모두 용서한다. 감히 유지(宥旨) 이전의 일을 서로 고언(告言)하는 자는 그 죄로써 죄준다. 벼슬에 있는 자는 각각 한 계자(階資)를 올리되 자궁(資窮)된 자는 대가(代加)한다. 직첩(職牒)을 거둔 자는 도로 준다. 도(徒)·유(流)·부처(付處)·정속(定屬)된 자는 경중을 가려서 방석(放釋)한다. 아, 그지없이 조심하면 이제부터 새로워지고, 은미한 곳에서도 신명을 대한 듯이 하면 장래에 명(命)을 유지할 것이다. 그러므로 교시(敎示)하니 잘 알아야 할 것이다." 【 의정부 우참찬(議政府右參贊) 신광한(申光漢)이 지은 것이다.】\r\n\t\t\t\t\t\t\r\n\r\n\t\t\t\t\t\t\r\n\t\t\t\t\t\t',
#   'category': ['사법(司法)']}]

# %% [markdown]
# ### Q2. Q1에서 만든 csv파일을 불러와서 DataFrame을 생성하고, content 칼럼에서 괄호와 한문을 모두 제거하여 content 칼럼에 다시 저장하세요.
# hint: 괄호와 괄호 안 문자를 제거하는 정규표현식 ```"\(.*\)" ```

# %%
injong_sillok = pd.DataFrame(all_articles)
injong_sillok['content'] = injong_sillok['content'].str.replace(r'\r|\n|\t|】|【|', '') # r은 붙이기 \가 뒤에있는 글자가 특수문자라는것
injong_sillok['content'] = injong_sillok['content'].str.replace(r'\([^)]*\)', '')
injong_sillok['content'] = injong_sillok['content'].str.replace(r'\d+\)', '')
injong_sillok['content']

# %%
#문자열 다루는게 어려움
# 정규표현식(나중에 알려주실 예정) | 이게 or 뜻임

# %% [markdown]
# ### Q3. Q2에서 만든 list of dictionaries을 pandas DataFrame으로 바꾸어 csv 파일로 저장하는 코드를 작성하세요.

# %%
injong_sillok.to_csv('injong_sillok.csv',index=False)
