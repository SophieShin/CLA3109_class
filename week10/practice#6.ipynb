# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import sklearn
# %matplotlib inline

# %% [markdown]
# ### practice1. Anatomy of a Figure

# %% [markdown]
#  - Figure

# %%
plt.gcf() # get current function

# %%
fig = plt.figure()
fig, ax = plt.subplots()
fig, axs = plt.subplots(2, 2)
ax1 = fig.add_subplot(2, 2, 3) # 2*2 개 중에 3번째꺼를 선택해서 ax1로 저장

# %% [markdown]
#  - plot

# %%
data1, data2, data3, data4 = np.random.randn(4, 100) # 100개짜리 4세트
fig, ax = plt.subplots(figsize = (5, 2.7)) 
x = np.arange(len(data1))
ax.plot(x, np.cumsum(data1), color = 'blue', linewidth = 3, linestyle = '--')
l,= ax.plot(x, np.cumsum(data2), color = 'orange', linewidth = 2) # 이게 line을 리턴 첫번째것만 갖고 오겠음
l.set_linestyle(':')
l.set_color('green')

# %% [markdown]
#  - color, linestyle, marker를 원하는 것으로 바꿔보세요.

# %%
fig = plt.figure()  # an empty figure with no Axes
fig, ax = plt.subplots()  # a figure with a single Axes
plt.plot(x, np.cumsum(data1), color='pink', linestyle='-.', marker = '^')

# %% [markdown]
#  - Scale

# %%
fig, axs = plt.subplots(1, 2, figsize = (5, 2.7))
x = np.linspace(0, 3, 100)
y = 1.5 * np.exp(1.5*x)
axs[0].plot(x, y)
axs[1].set_yscale('log')
axs[1].plot(x, y)

# %% [markdown]
#  - Legend

# %%
mu, sigma = 115, 15
x = mu + sigma * np.random.randn(10000)
fig, ax = plt.subplots(figsize = (5, 2.7))

ax.hist(x, 50, density =1, facecolor = 'blue', alpha = 0.5)
ax.set_xticks(np.arange(40, 180, 10))
ax.set_xlabel('Length [cm]')
ax.set_ylabel('Probability')
ax.set_title('Normal Distribution')
ax.legend(loc = 'best', labels = ['hist'])

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(1)

N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = (30*np.random.rand(N))**2

plt.scatter(x, y, s = area, c=colors, alpha = 0.5) #s는 면적
plt.colorbar()

# %%
area
# Out:
# array([4.66226724e+00, 8.42061149e+02, 2.90464321e+02, 3.71953253e+01,
#        5.73014532e+01, 4.97949211e+02, 3.43734139e+01, 3.04180382e+02,
#        8.46844901e+02, 6.45407117e+02, 5.17742528e+01, 2.19427678e+02,
#        3.45910583e+02, 6.18488399e+02, 2.21251873e+01, 3.10567759e-01,
#        4.41279055e+00, 2.12878410e+02, 3.30871874e+02, 2.91232762e+02,
#        9.06470090e+01, 8.79625711e+02, 3.02494067e+02, 1.30056580e+02,
#        2.73189546e+02, 4.99971073e+02, 4.03085399e+02, 6.31641348e+01,
#        3.96027923e+00, 1.23266082e+02, 3.56889725e+02, 3.97558030e+01,
#        5.09976831e+02, 3.98439302e+00, 6.09875555e+01, 5.82866917e+02,
#        3.36751395e+01, 3.68019196e+02, 2.47751040e+02, 7.69742804e+02,
#        6.23926704e+01, 3.91577894e+00, 4.86289773e+02, 5.36633018e+02,
#        7.41716660e+02, 7.81714744e+02, 1.75181750e-01, 4.94330287e+01,
#        3.42373987e+02, 8.10568779e+02])

# %% [markdown]
#  - bar plot

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots()
x = np.arange(3)
years = ['2018', '2019', '2020']
values = [100, 400, 900]

ax.bar(x, values)
plt.xticks(x, years)
plt.show()

# %%
labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 35, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]
men_std = [2,3,4,1,2]
women_std=[3,5,2,3,3]
width = .35

fig, ax = plt.subplots()
ax.bar(labels, men_means, width, yerr = men_std, label = 'Men')
ax.bar(labels, women_means, width, yerr = women_std, bottom= men_means, label = 'Women')

ax.set_ylabel('Score')
ax.set_title('Scores by group and gender')
ax.legend()

# %%
x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)

kwargs = dict(histtype = 'stepfilled', alpha = 0.3, bins = 40)

plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs)
# Out:
# (array([ 1.,  1.,  1.,  0.,  3.,  3.,  4.,  9.,  7., 10., 24., 21., 28.,
#         33., 52., 46., 55., 63., 51., 61., 72., 50., 58., 46., 53., 47.,
#         31., 43., 33., 28., 19., 13., 13.,  8.,  7.,  2.,  2.,  1.,  0.,
#          1.]),
#  array([-3.62168512, -3.29887455, -2.97606397, -2.6532534 , -2.33044282,
#         -2.00763224, -1.68482167, -1.36201109, -1.03920051, -0.71638994,
#         -0.39357936, -0.07076879,  0.25204179,  0.57485237,  0.89766294,
#          1.22047352,  1.5432841 ,  1.86609467,  2.18890525,  2.51171583,
#          2.8345264 ,  3.15733698,  3.48014755,  3.80295813,  4.12576871,
#          4.44857928,  4.77138986,  5.09420044,  5.41701101,  5.73982159,
#          6.06263216,  6.38544274,  6.70825332,  7.03106389,  7.35387447,
#          7.67668505,  7.99949562,  8.3223062 ,  8.64511677,  8.96792735,
#          9.29073793]),
#  [<matplotlib.patches.Polygon at 0x137d9e0db20>])

# %% [markdown]
# ### Seaborn 실습

# %% [markdown]
#  - scatter plot

# %%
import seaborn as sns

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="time")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="time", style="time")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
#  - histplot

# %%
penguins = sns.load_dataset("penguins")
sns.histplot(data=penguins, x="flipper_length_mm")
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.histplot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack")
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %% [markdown]
#  - kdeplot

# %%
iris = sns.load_dataset("iris")
sns.kdeplot(data=iris)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.kdeplot(data=tips, x="total_bill", hue="time", multiple="stack")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(
   data=tips, x="total_bill", hue="size",
   fill=True, common_norm=False, palette="crest",
   alpha=.5, linewidth=0,
)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %% [markdown]
#  - swarmplot

# %%
tips = sns.load_dataset("tips")
ax = sns.swarmplot(x=tips["total_bill"])

# %%
ax = sns.swarmplot(x="day", y="total_bill", data=tips)

# %%
ax = sns.boxplot(x="total_bill", y="day", data=tips, whis=np.inf)
ax = sns.swarmplot(x="total_bill", y="day", data=tips, color=".2")

# %% [markdown]
#  - heatmap

# %%
flights = sns.load_dataset("flights")
flights = flights.pivot("month", "year", "passengers")
ax = sns.heatmap(flights)

# %%
ax = sns.heatmap(flights, cmap="YlGnBu")
